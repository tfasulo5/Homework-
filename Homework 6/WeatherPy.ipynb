# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
city=["New York"]
temp = ["temperature"]
humidity = ["humidity"]
cloudiness = ["cloudiness"]
wind_speed = ["wind speed"]
lat = ["latitude"]
long = ["longtitude"]

base_url = f"http://api.openweathermap.org/data/2.5/weather?"
weather_url = f"{base_url}units=Imperial&appid={api_key}&q="
print(weather_url)


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=c07f06e7afc470606c05ea0ac7a5cd61&q=

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_response = requests.get(weather_url)
weather_json = weather_response.json()
#cities = [len]
weather = pd.DataFrame(columns=["City Name", "Temperature", "Humidity", "Cloudiness", "Wind Speed", "Latitude", "Longitiude"])
weather
for i, city in enumerate (cities): 
    print(i)
    print(city)
    weather.loc[i, "City Name"] = city
    
    response = requests.get(weather_url + city)
    #response = requests.get(weather_url + temp)
    #print(response.url)
    response = response.json()
    
    #print(response)
    try: 
         
        temp = response["main"]["temp"] - 273
        humidity = response["main"]["humidity"]
        cloudiness = response["clouds"]["all"]
        wind_speed = reponse["wind"]["speed"]
        lat = reponse["coord"]["lat"]
        long = reponse["coord"]["lon"]
        print(f"Please wait while getting temperature for {city}")
        print(f"The temperature in {city} is {temp}")
        print(f"The humidity in {city} is {humidity}")
        print(f"The cloudiness in {city} is {cloudiness}")
        print(f"The windspeed in {city} is {wind_speed}")
        print(f"The coordinates for {city} is {lat}")
        print(f"The coordinates for {city} is {long}")
        
    except: 
        print(f"{city} is not available")
        print(f"{temp} is not available")
        print(f"{humidity} is not available")
        print(f"{cloudiness}is not available")
        print(f"{wind_speed}is not available")
        print(f"{lat}is not available")      
        print(f"{long}is not available")      

    #print(f"The temperature in {city} is {temp}")
    weather.loc[i, "Temperature"] = temp
    weather.loc[i, "City Name"] = city
    weather.loc[i, "Humidity"] = humidity
    weather.loc[i, "Cloudiness"] = cloudiness
    weather.loc[i, "Wind Speed"] = wind_speed
    weather.loc[i, "Latitude"] = lat
    weather.loc[i, "Longititude"] = long

weather
# Out:
# 0
# kashan
# kashan is not available
# ['temperature'] is not available
# ['humidity'] is not available
# ['cloudiness']is not available
# ['wind speed']is not available
# ['latitude']is not available
# ['longtitude']is not available
# 1
# busselton
# busselton is not available
# ['temperature'] is not available
# ['humidity'] is not available
# ['cloudiness']is not available
# ['wind speed']is not available
# ['latitude']is not available
# ['longtitude']is not available
# 2
# lagoa
# lagoa is not available
# ['temperature'] is not available
# ['humidity'] is not available
# ['cloudiness']is not available
# ['wind speed']is not available
# ['latitude']is not available
# ['longtitude']is not available
# 3
# castro
# castro is not available
# ['temperature'] is not available
# ['humidity'] is not available
# ['cloudiness']is not available
# ['wind speed']is not available
# ['latitude']is not available
# ['longtitude']is not available
# 4
# kapaa
# kapaa is not available
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = ("output_data/cities.csv")
weather_data
# Out:
# 'output_data/cities.csv'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["temp"], marker="o", s=10)

plt.title("Latitude vs.Temperature")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-72ae1bdf1d38> in <module>
# ----> 1 plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)
#       2
#       3 plt.title("Latitude vs.Temperature")
#       4 plt.ylabel("Temperature")
#       5 plt.xlabel("Latitude")
#
# NameError: name 'weather_data' is not defined

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

plt.title("Latitude vs.Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
