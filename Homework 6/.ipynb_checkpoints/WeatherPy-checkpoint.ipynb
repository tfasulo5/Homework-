# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
city="cleveland "
base_url = f"http://api.openweathermap.org/data/2.5/weather?"
weather_url = f"{base_url}appid={api_key}&q="
print(weather_url)


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=c07f06e7afc470606c05ea0ac7a5cd61&q=

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# weather_response = requests.get(weather_url)
# weather_json = weather_response.json()
#cities = [len]
weather = pd.DataFrame(columns=["City Name", "Temperature", "Humidity", "Cloudiness", "Wind Speed", "Latitude", "Longitiude"])
weather
for i, city in enumerate (cities): 
    print(i)
    print(city)
    weather.loc[i, "City Name"] = city
    
    response = requests.get(weather_url + city)
    #print(response.url)
    response = response.json()
    #print(response)
    try: 
        
        temp = response["main"]["temp"] - 273
        print(f"Please wait while getting temperature for {city}")
        print(f"The temperature in {city} is {temp}")
    except: 
        print(f"{city} is not available")
  

    print(f"The temperature in {city} is {temp}")
    weather.loc[i, "Temperature"] = temp
    weather.loc[i, "City Name"] = city
     
    

weather
    
    
    
#     #for index, row in cities_pd.iterrows():
#     # get lat, lng from df
#     lats = row["Lats"]
#     lngs = row["Lngs"]

#     # make request and print url
#     response = requests.get(base_url, )
    
# # #     print the name_address url, avoid doing for public github repos in order to avoid exposing key
# # #     print(name_address.url)

#      # convert to json
#      name_address = name_address.json()
#     print(json.dumps(name_address, indent=4, sort_keys=True))

# #     # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
#      try:
#         cities_pd.loc[index, ""] = name_address[""][0][""]
#         cities_pd.loc[index, ""] = name_address[""][0][""]
#         cities_pd.loc[index, ""] = name_address[""][0][""]
#         except (KeyError, IndexError):
#         print("Missing field/result... skipping.")
# Out:
# 0
# maiduguri
# Please wait while getting temperature maiduguri
# The temperature in maiduguri is 32.012
# Please wait while getting temperature maiduguri
# The temperature in maiduguri is 32.012
# 1
# vaini
# Please wait while getting temperature vaini
# The temperature in vaini is 24.312000000000012
# Please wait while getting temperature vaini
# The temperature in vaini is 24.312000000000012
# 2
# doctor pedro p. pena
# doctor pedro p. pena is not available
# Please wait while getting temperature doctor pedro p. pena
# The temperature in doctor pedro p. pena is 24.312000000000012
# 3
# rikitea
# Please wait while getting temperature rikitea
# The temperature in rikitea is 19.21199999999999
# Please wait while getting temperature rikitea
# The temperature in rikitea is 19.21199999999999
# 4
# kavieng
# Please wait while getting temperature kavieng
# The temperature in kavieng is 27.411999999999978
# Please wait while getting temperature kavieng
# The temperature in kavieng is 27.411999999999978
# 5
# hvolsvollur
# hvolsvollur is not available
# Please wait while getting temperature hvolsvollur
# The temperature in hvolsvollur is 27.411999999999978
# 6
# hilo
# Please wait while getting temperature hilo
# The temperature in hilo is 24.819999999999993
# Please wait while getting temperature hilo
# The temperature in hilo is 24.819999999999993
# 7
# dikson
# Please wait while getting temperature dikson
# The temperature in dikson is 6.812000000000012
# Please wait while getting temperature dikson
# The temperature in dikson is 6.812000000000012
# 8
# klaksvik
# Please wait while getting temperature klaksvik
# The temperature in klaksvik is 10.149999999999977
# Please wait while getting temperature klaksvik
# The temperature in klaksvik is 10.149999999999977
# 9
# faya
# Please wait while getting temperature faya
# The temperature in faya is 24.670000000000016
# Please wait while getting temperature faya
# The temperature in faya is 24.670000000000016
# 10
# airai
# Please wait while getting temperature airai
# The temperature in airai is 18.812000000000012
# Please wait while getting temperature airai
# The temperature in airai is 18.812000000000012
# 11
# husavik
# Please wait while getting temperature husavik
# The temperature in husavik is 14.04000000000002
# Please wait while getting temperature husavik
# The temperature in husavik is 14.04000000000002
# 12
# ushuaia
# Please wait while getting temperature ushuaia
# The temperature in ushuaia is 6.149999999999977
# Please wait while getting temperature ushuaia
# The temperature in ushuaia is 6.149999999999977
# 13
# saint george
# Please wait while getting temperature saint george
# The temperature in saint george is 24.470000000000027
# Please wait while getting temperature saint george
# The temperature in saint george is 24.470000000000027
# 14
# punta arenas
# Please wait while getting temperature punta arenas
# The temperature in punta arenas is 6.240000000000009
# Please wait while getting temperature punta arenas
# The temperature in punta arenas is 6.240000000000009
# 15
# olinda
# Please wait while getting temperature olinda
# The temperature in olinda is 7.699999999999989
# Please wait while getting temperature olinda
# The temperature in olinda is 7.699999999999989
# 16
# kamenskoye
# kamenskoye is not available
# Please wait while getting temperature kamenskoye
# The temperature in kamenskoye is 7.699999999999989
# 17
# nemuro
# Please wait while getting temperature nemuro
# The temperature in nemuro is 19.112000000000023
# Please wait while getting temperature nemuro
# The temperature in nemuro is 19.112000000000023
# 18
# salisbury
# Please wait while getting temperature salisbury
# The temperature in salisbury is 15.399999999999977
# Please wait while getting temperature salisbury
# The temperature in salisbury is 15.399999999999977
# 19
# tilichiki
# Please wait while getting temperature tilichiki
# The temperature in tilichiki is 7.312000000000012
# Please wait while getting temperature tilichiki
# The temperature in tilichiki is 7.312000000000012
# 20
# hobart
# Please wait while getting temperature hobart
# The temperature in hobart is 4.220000000000027
# Please wait while getting temperature hobart
# The temperature in hobart is 4.220000000000027
# 21
# hasaki
# Please wait while getting temperature hasaki
# The temperature in hasaki is 24.420000000000016
# Please wait while getting temperature hasaki
# The temperature in hasaki is 24.420000000000016
# 22
# maceio
# Please wait while getting temperature maceio
# The temperature in maceio is 26.149999999999977
# Please wait while getting temperature maceio
# The temperature in maceio is 26.149999999999977
# 23
# carnarvon
# Please wait while getting temperature carnarvon
# The temperature in carnarvon is 19.312000000000012
# Please wait while getting temperature carnarvon
# The temperature in carnarvon is 19.312000000000012
# 24
# nikolskoye
# Please wait while getting temperature nikolskoye
# The temperature in nikolskoye is 13.339999999999975
# Please wait while getting temperature nikolskoye
# The temperature in nikolskoye is 13.339999999999975
# 25
# yakeshi
# Please wait while getting temperature yakeshi
# The temperature in yakeshi is 10.911999999999978
# Please wait while getting temperature yakeshi
# The temperature in yakeshi is 10.911999999999978
# 26
# cape town
# Please wait while getting temperature cape town
# The temperature in cape town is 23.100000000000023
# Please wait while getting temperature cape town
# The temperature in cape town is 23.100000000000023
# 27
# ereymentau
# Please wait while getting temperature ereymentau
# The temperature in ereymentau is 11.411999999999978
# Please wait while getting temperature ereymentau
# The temperature in ereymentau is 11.411999999999978
# 28
# qaanaaq
# Please wait while getting temperature qaanaaq
# The temperature in qaanaaq is 0.21199999999998909
# Please wait while getting temperature qaanaaq
# The temperature in qaanaaq is 0.21199999999998909
# 29
# atuona
# Please wait while getting temperature atuona
# The temperature in atuona is 26.112000000000023
# Please wait while getting temperature atuona
# The temperature in atuona is 26.112000000000023
# 30
# dubbo
# Please wait while getting temperature dubbo
# The temperature in dubbo is 11.149999999999977
# Please wait while getting temperature dubbo
# The temperature in dubbo is 11.149999999999977
# 31
# yellowknife
# Please wait while getting temperature yellowknife
# The temperature in yellowknife is 10.879999999999995
# Please wait while getting temperature yellowknife
# The temperature in yellowknife is 10.879999999999995
# 32
# codrington
# Please wait while getting temperature codrington
# The temperature in codrington is 11.610000000000014
# Please wait while getting temperature codrington
# The temperature in codrington is 11.610000000000014
# 33
# lagoa
# Please wait while getting temperature lagoa
# The temperature in lagoa is 25.44999999999999
# Please wait while getting temperature lagoa
# The temperature in lagoa is 25.44999999999999
# 34
# mar del plata
# Please wait while getting temperature mar del plata
# The temperature in mar del plata is 10.512
# Please wait while getting temperature mar del plata
# The temperature in mar del plata is 10.512
# 35
# vychegodskiy
# Please wait while getting temperature vychegodskiy
# The temperature in vychegodskiy is 11.612000000000023
# Please wait while getting temperature vychegodskiy
# The temperature in vychegodskiy is 11.612000000000023
# 36
# hutchinson
# Please wait while getting temperature hutchinson
# The temperature in hutchinson is 31.75999999999999
# Please wait while getting temperature hutchinson
# The temperature in hutchinson is 31.75999999999999
# 37
# lukang
# Please wait while getting temperature lukang
# The temperature in lukang is 26.5
# Please wait while getting temperature lukang
# The temperature in lukang is 26.5
# 38
# illoqqortoormiut
# illoqqortoormiut is not available
# Please wait while getting temperature illoqqortoormiut
# The temperature in illoqqortoormiut is 26.5
# 39
# attawapiskat
# attawapiskat is not available
# Please wait while getting temperature attawapiskat
# The temperature in attawapiskat is 26.5
# 40
# healdsburg
# Please wait while getting temperature healdsburg
# The temperature in healdsburg is 17.970000000000027
# Please wait while getting temperature healdsburg
# The temperature in healdsburg is 17.970000000000027
# 41
# mataura
# Please wait while getting temperature mataura
# The temperature in mataura is 5.149999999999977
# Please wait while getting temperature mataura
# The temperature in mataura is 5.149999999999977
# 42
# albany
# Please wait while getting temperature albany
# The temperature in albany is 20.350000000000023
# Please wait while getting temperature albany
# The temperature in albany is 20.350000000000023
# 43
# bhimunipatnam
# Please wait while getting temperature bhimunipatnam
# The temperature in bhimunipatnam is 28.149999999999977
# Please wait while getting temperature bhimunipatnam
# The temperature in bhimunipatnam is 28.149999999999977
# 44
# jamestown
# Please wait while getting temperature jamestown
# The temperature in jamestown is 6.112000000000023
# Please wait while getting temperature jamestown
# The temperature in jamestown is 6.112000000000023
# 45
# barrow
# Please wait while getting temperature barrow
# The temperature in barrow is 13.112000000000023
# Please wait while getting temperature barrow
# The temperature in barrow is 13.112000000000023
# 46
# saint-philippe
# Please wait while getting temperature saint-philippe
# The temperature in saint-philippe is 19.480000000000018
# Please wait while getting temperature saint-philippe
# The temperature in saint-philippe is 19.480000000000018
# 47
# busselton
# Please wait while getting temperature busselton
# The temperature in busselton is 6.389999999999986
# Please wait while getting temperature busselton
# The temperature in busselton is 6.389999999999986
# 48
# hithadhoo
# Please wait while getting temperature hithadhoo
# The temperature in hithadhoo is 28.512
# Please wait while getting temperature hithadhoo
# The temperature in hithadhoo is 28.512
# 49
# avarua
# Please wait while getting temperature avarua
# The temperature in avarua is 24.149999999999977
# Please wait while getting temperature avarua
# The temperature in avarua is 24.149999999999977
# 50
# porto novo
# Please wait while getting temperature porto novo
# The temperature in porto novo is 28.149999999999977
# Please wait while getting temperature porto novo
# The temperature in porto novo is 28.149999999999977
# 51
# tiruttani
# Please wait while getting temperature tiruttani
# The temperature in tiruttani is 31.149999999999977
# Please wait while getting temperature tiruttani
# The temperature in tiruttani is 31.149999999999977
# 52
# bayshore gardens
# Please wait while getting temperature bayshore gardens
# The temperature in bayshore gardens is 31.819999999999993
# Please wait while getting temperature bayshore gardens
# The temperature in bayshore gardens is 31.819999999999993
# 53
# new norfolk
# Please wait while getting temperature new norfolk
# The temperature in new norfolk is 4.230000000000018
# Please wait while getting temperature new norfolk
# The temperature in new norfolk is 4.230000000000018
# 54
# beyneu
# Please wait while getting temperature beyneu
# The temperature in beyneu is 19.411999999999978
# Please wait while getting temperature beyneu
# The temperature in beyneu is 19.411999999999978
# 55
# belaya gora
# Please wait while getting temperature belaya gora
# The temperature in belaya gora is 3.9119999999999777
# Please wait while getting temperature belaya gora
# The temperature in belaya gora is 3.9119999999999777
# 56
# brenham
# Please wait while getting temperature brenham
# The temperature in brenham is 35.35000000000002
# Please wait while getting temperature brenham
# The temperature in brenham is 35.35000000000002
# 57
# talnakh
# Please wait while getting temperature talnakh
# The temperature in talnakh is 12.149999999999977
# Please wait while getting temperature talnakh
# The temperature in talnakh is 12.149999999999977
# 58
# ofaqim
# Please wait while getting temperature ofaqim
# The temperature in ofaqim is 26.579999999999984
# Please wait while getting temperature ofaqim
# The temperature in ofaqim is 26.579999999999984
# 59
# bluff
# Please wait while getting temperature bluff
# The temperature in bluff is 12.112000000000023
# Please wait while getting temperature bluff
# The temperature in bluff is 12.112000000000023
# 60
# tuktoyaktuk
# Please wait while getting temperature tuktoyaktuk
# The temperature in tuktoyaktuk is 13.149999999999977
# Please wait while getting temperature tuktoyaktuk
# The temperature in tuktoyaktuk is 13.149999999999977
# 61
# inirida
# Please wait while getting temperature inirida
# The temperature in inirida is 35.91199999999998
# Please wait while getting temperature inirida
# The temperature in inirida is 35.91199999999998
# 62
# lebu
# Please wait while getting temperature lebu
# The temperature in lebu is 14.012
# Please wait while getting temperature lebu
# The temperature in lebu is 14.012
# 63
# boa vista
# Please wait while getting temperature boa vista
# The temperature in boa vista is 31.149999999999977
# Please wait while getting temperature boa vista
# The temperature in boa vista is 31.149999999999977
# 64
# cabo san lucas
# Please wait while getting temperature cabo san lucas
# The temperature in cabo san lucas is 31.180000000000007
# Please wait while getting temperature cabo san lucas
# The temperature in cabo san lucas is 31.180000000000007
# 65
# barentsburg
# barentsburg is not available
# Please wait while getting temperature barentsburg
# The temperature in barentsburg is 31.180000000000007
# 66
# komsomolskiy
# Please wait while getting temperature komsomolskiy
# The temperature in komsomolskiy is 11.711999999999989
# Please wait while getting temperature komsomolskiy
# The temperature in komsomolskiy is 11.711999999999989
# 67
# beringovskiy
# Please wait while getting temperature beringovskiy
# The temperature in beringovskiy is 4.911999999999978
# Please wait while getting temperature beringovskiy
# The temperature in beringovskiy is 4.911999999999978
# 68
# belushya guba
# belushya guba is not available
# Please wait while getting temperature belushya guba
# The temperature in belushya guba is 4.911999999999978
# 69
# talcahuano
# Please wait while getting temperature talcahuano
# The temperature in talcahuano is 13.149999999999977
# Please wait while getting temperature talcahuano
# The temperature in talcahuano is 13.149999999999977
# 70
# fairbanks
# Please wait while getting temperature fairbanks
# The temperature in fairbanks is 10.720000000000027
# Please wait while getting temperature fairbanks
# The temperature in fairbanks is 10.720000000000027
# 71
# tabou
# Please wait while getting temperature tabou
# The temperature in tabou is 25.21199999999999
# Please wait while getting temperature tabou
# The temperature in tabou is 25.21199999999999
# 72
# saint-pierre
# Please wait while getting temperature saint-pierre
# The temperature in saint-pierre is 14.5
# Please wait while getting temperature saint-pierre
# The temperature in saint-pierre is 14.5
# 73
# cidreira
# Please wait while getting temperature cidreira
# The temperature in cidreira is 20.21199999999999
# Please wait while getting temperature cidreira
# The temperature in cidreira is 20.21199999999999
# 74
# acapulco
# Please wait while getting temperature acapulco
# The temperature in acapulco is 31.149999999999977
# Please wait while getting temperature acapulco
# The temperature in acapulco is 31.149999999999977
# 75
# rocha
# Please wait while getting temperature rocha
# The temperature in rocha is 18.512
# Please wait while getting temperature rocha
# The temperature in rocha is 18.512
# 76
# victoria
# Please wait while getting temperature victoria
# The temperature in victoria is 27.529999999999973
# Please wait while getting temperature victoria
# The temperature in victoria is 27.529999999999973
# 77
# deputatskiy
# Please wait while getting temperature deputatskiy
# The temperature in deputatskiy is 3.0120000000000005
# Please wait while getting temperature deputatskiy
# The temperature in deputatskiy is 3.0120000000000005
# 78
# saldanha
# Please wait while getting temperature saldanha
# The temperature in saldanha is 24.71199999999999
# Please wait while getting temperature saldanha
# The temperature in saldanha is 24.71199999999999
# 79
# lompoc
# Please wait while getting temperature lompoc
# The temperature in lompoc is 23.269999999999982
# Please wait while getting temperature lompoc
# The temperature in lompoc is 23.269999999999982
# 80
# tasiilaq
# Please wait while getting temperature tasiilaq
# The temperature in tasiilaq is 5.149999999999977
# Please wait while getting temperature tasiilaq
# The temperature in tasiilaq is 5.149999999999977
# 81
# hualmay
# Please wait while getting temperature hualmay
# The temperature in hualmay is 15.911999999999978
# Please wait while getting temperature hualmay
# The temperature in hualmay is 15.911999999999978
# 82
# chernyshevskiy
# Please wait while getting temperature chernyshevskiy
# The temperature in chernyshevskiy is 4.211999999999989
# Please wait while getting temperature chernyshevskiy
# The temperature in chernyshevskiy is 4.211999999999989
# 83
# kadykchan
# kadykchan is not available
# Please wait while getting temperature kadykchan
# The temperature in kadykchan is 4.211999999999989
# 84
# nizwa
# Please wait while getting temperature nizwa
# The temperature in nizwa is 33.91199999999998
# Please wait while getting temperature nizwa
# The temperature in nizwa is 33.91199999999998
# 85
# antofagasta
# Please wait while getting temperature antofagasta
# The temperature in antofagasta is 16.149999999999977
# Please wait while getting temperature antofagasta
# The temperature in antofagasta is 16.149999999999977
# 86
# nerchinskiy zavod
# Please wait while getting temperature nerchinskiy zavod
# The temperature in nerchinskiy zavod is 7.5120000000000005
# Please wait while getting temperature nerchinskiy zavod
# The temperature in nerchinskiy zavod is 7.5120000000000005
# 87
# phan thiet
# Please wait while getting temperature phan thiet
# The temperature in phan thiet is 24.21199999999999
# Please wait while getting temperature phan thiet
# The temperature in phan thiet is 24.21199999999999
# 88
# bairiki
# bairiki is not available
# Please wait while getting temperature bairiki
# The temperature in bairiki is 24.21199999999999
# 89
# thompson
# Please wait while getting temperature thompson
# The temperature in thompson is 16.149999999999977
# Please wait while getting temperature thompson
# The temperature in thompson is 16.149999999999977
# 90
# bambous virieux
# Please wait while getting temperature bambous virieux
# The temperature in bambous virieux is 22.420000000000016
# Please wait while getting temperature bambous virieux
# The temperature in bambous virieux is 22.420000000000016
# 91
# dandong
# Please wait while getting temperature dandong
# The temperature in dandong is 20.612000000000023
# Please wait while getting temperature dandong
# The temperature in dandong is 20.612000000000023
# 92
# butaritari
# Please wait while getting temperature butaritari
# The temperature in butaritari is 29.411999999999978
# Please wait while getting temperature butaritari
# The temperature in butaritari is 29.411999999999978
# 93
# ulan-ude
# Please wait while getting temperature ulan-ude
# The temperature in ulan-ude is 6.149999999999977
# Please wait while getting temperature ulan-ude
# The temperature in ulan-ude is 6.149999999999977
# 94
# fort saint james
# Please wait while getting temperature fort saint james
# The temperature in fort saint james is 18.312000000000012
# Please wait while getting temperature fort saint james
# The temperature in fort saint james is 18.312000000000012
# 95
# torbay
# Please wait while getting temperature torbay
# The temperature in torbay is 14.220000000000027
# Please wait while getting temperature torbay
# The temperature in torbay is 14.220000000000027
# 96
# abu dhabi
# Please wait while getting temperature abu dhabi
# The temperature in abu dhabi is 34.629999999999995
# Please wait while getting temperature abu dhabi
# The temperature in abu dhabi is 34.629999999999995
# 97
# leningradskiy
# Please wait while getting temperature leningradskiy
# The temperature in leningradskiy is 5.911999999999978
# Please wait while getting temperature leningradskiy
# The temperature in leningradskiy is 5.911999999999978
# 98
# palabuhanratu
# palabuhanratu is not available
# Please wait while getting temperature palabuhanratu
# The temperature in palabuhanratu is 5.911999999999978
# 99
# zhob
# Please wait while getting temperature zhob
# The temperature in zhob is 24.612000000000023
# Please wait while getting temperature zhob
# The temperature in zhob is 24.612000000000023
# 100
# lavrentiya
# Please wait while getting temperature lavrentiya
# The temperature in lavrentiya is 7.5120000000000005
# Please wait while getting temperature lavrentiya
# The temperature in lavrentiya is 7.5120000000000005
# 101
# natchitoches
# Please wait while getting temperature natchitoches
# The temperature in natchitoches is 36.54000000000002
# Please wait while getting temperature natchitoches
# The temperature in natchitoches is 36.54000000000002
# 102
# westport
# Please wait while getting temperature westport
# The temperature in westport is 22.5
# Please wait while getting temperature westport
# The temperature in westport is 22.5
# 103
# bela
# Please wait while getting temperature bela
# The temperature in bela is 28.812000000000012
# Please wait while getting temperature bela
# The temperature in bela is 28.812000000000012
# 104
# sirjan
# Please wait while getting temperature sirjan
# The temperature in sirjan is 23.812000000000012
# Please wait while getting temperature sirjan
# The temperature in sirjan is 23.812000000000012
# 105
# saskylakh
# Please wait while getting temperature saskylakh
# The temperature in saskylakh is 8.512
# Please wait while getting temperature saskylakh
# The temperature in saskylakh is 8.512
# 106
# neryungri
# Please wait while getting temperature neryungri
# The temperature in neryungri is 6.911999999999978
# Please wait while getting temperature neryungri
# The temperature in neryungri is 6.911999999999978
# 107
# ouadda
# Please wait while getting temperature ouadda
# The temperature in ouadda is 21.312000000000012
# Please wait while getting temperature ouadda
# The temperature in ouadda is 21.312000000000012
# 108
# athabasca
# Please wait while getting temperature athabasca
# The temperature in athabasca is 12.211999999999989
# Please wait while getting temperature athabasca
# The temperature in athabasca is 12.211999999999989
# 109
# arraial do cabo
# Please wait while getting temperature arraial do cabo
# The temperature in arraial do cabo is 24.149999999999977
# Please wait while getting temperature arraial do cabo
# The temperature in arraial do cabo is 24.149999999999977
# 110
# cedar city
# Please wait while getting temperature cedar city
# The temperature in cedar city is 26.600000000000023
# Please wait while getting temperature cedar city
# The temperature in cedar city is 26.600000000000023
# 111
# mahebourg
# Please wait while getting temperature mahebourg
# The temperature in mahebourg is 22.370000000000005
# Please wait while getting temperature mahebourg
# The temperature in mahebourg is 22.370000000000005
# 112
# kruisfontein
# Please wait while getting temperature kruisfontein
# The temperature in kruisfontein is 18.411999999999978
# Please wait while getting temperature kruisfontein
# The temperature in kruisfontein is 18.411999999999978
# 113
# puerto ayora
# Please wait while getting temperature puerto ayora
# The temperature in puerto ayora is 23.75
# Please wait while getting temperature puerto ayora
# The temperature in puerto ayora is 23.75
# 114
# half moon bay
# Please wait while getting temperature half moon bay
# The temperature in half moon bay is 18.560000000000002
# Please wait while getting temperature half moon bay
# The temperature in half moon bay is 18.560000000000002
# 115
# yulara
# Please wait while getting temperature yulara
# The temperature in yulara is 13.149999999999977
# Please wait while getting temperature yulara
# The temperature in yulara is 13.149999999999977
# 116
# tautira
# Please wait while getting temperature tautira
# The temperature in tautira is 24.670000000000016
# Please wait while getting temperature tautira
# The temperature in tautira is 24.670000000000016
# 117
# katsuura
# Please wait while getting temperature katsuura
# The temperature in katsuura is 25.54000000000002
# Please wait while getting temperature katsuura
# The temperature in katsuura is 25.54000000000002
# 118
# grand-lahou
# Please wait while getting temperature grand-lahou
# The temperature in grand-lahou is 25.112000000000023
# Please wait while getting temperature grand-lahou
# The temperature in grand-lahou is 25.112000000000023
# 119
# khatanga
# Please wait while getting temperature khatanga
# The temperature in khatanga is 10.612000000000023
# Please wait while getting temperature khatanga
# The temperature in khatanga is 10.612000000000023
# 120
# kaitangata
# Please wait while getting temperature kaitangata
# The temperature in kaitangata is 5.149999999999977
# Please wait while getting temperature kaitangata
# The temperature in kaitangata is 5.149999999999977
# 121
# wenling
# Please wait while getting temperature wenling
# The temperature in wenling is 25.220000000000027
# Please wait while getting temperature wenling
# The temperature in wenling is 25.220000000000027
# 122
# nevers
# Please wait while getting temperature nevers
# The temperature in nevers is 15.870000000000005
# Please wait while getting temperature nevers
# The temperature in nevers is 15.870000000000005
# 123
# upernavik
# Please wait while getting temperature upernavik
# The temperature in upernavik is 5.211999999999989
# Please wait while getting temperature upernavik
# The temperature in upernavik is 5.211999999999989
# 124
# pacific grove
# Please wait while getting temperature pacific grove
# The temperature in pacific grove is 18.639999999999986
# Please wait while getting temperature pacific grove
# The temperature in pacific grove is 18.639999999999986
# 125
# southbridge
# Please wait while getting temperature southbridge
# The temperature in southbridge is 20.74000000000001
# Please wait while getting temperature southbridge
# The temperature in southbridge is 20.74000000000001
# 126
# yar-sale
# Please wait while getting temperature yar-sale
# The temperature in yar-sale is 13.312000000000012
# Please wait while getting temperature yar-sale
# The temperature in yar-sale is 13.312000000000012
# 127
# belmonte
# Please wait while getting temperature belmonte
# The temperature in belmonte is 26.899999999999977
# Please wait while getting temperature belmonte
# The temperature in belmonte is 26.899999999999977
# 128
# mumford
# Please wait while getting temperature mumford
# The temperature in mumford is 24.012
# Please wait while getting temperature mumford
# The temperature in mumford is 24.012
# 129
# ampanihy
# Please wait while getting temperature ampanihy
# The temperature in ampanihy is 15.211999999999989
# Please wait while getting temperature ampanihy
# The temperature in ampanihy is 15.211999999999989
# 130
# constitucion
# Please wait while getting temperature constitucion
# The temperature in constitucion is 20.379999999999995
# Please wait while getting temperature constitucion
# The temperature in constitucion is 20.379999999999995
# 131
# itarema
# Please wait while getting temperature itarema
# The temperature in itarema is 31.312000000000012
# Please wait while getting temperature itarema
# The temperature in itarema is 31.312000000000012
# 132
# jiaocheng
# Please wait while getting temperature jiaocheng
# The temperature in jiaocheng is 22.312000000000012
# Please wait while getting temperature jiaocheng
# The temperature in jiaocheng is 22.312000000000012
# 133
# lata
# Please wait while getting temperature lata
# The temperature in lata is 4.0120000000000005
# Please wait while getting temperature lata
# The temperature in lata is 4.0120000000000005
# 134
# broken hill
# Please wait while getting temperature broken hill
# The temperature in broken hill is 6.149999999999977
# Please wait while getting temperature broken hill
# The temperature in broken hill is 6.149999999999977
# 135
# saleaula
# saleaula is not available
# Please wait while getting temperature saleaula
# The temperature in saleaula is 6.149999999999977
# 136
# farah
# Please wait while getting temperature farah
# The temperature in farah is 21.411999999999978
# Please wait while getting temperature farah
# The temperature in farah is 21.411999999999978
# 137
# burica
# burica is not available
# Please wait while getting temperature burica
# The temperature in burica is 21.411999999999978
# 138
# fare
# Please wait while getting temperature fare
# The temperature in fare is 23.512
# Please wait while getting temperature fare
# The temperature in fare is 23.512
# 139
# jutai
# Please wait while getting temperature jutai
# The temperature in jutai is 28.21199999999999
# Please wait while getting temperature jutai
# The temperature in jutai is 28.21199999999999
# 140
# teahupoo
# Please wait while getting temperature teahupoo
# The temperature in teahupoo is 24.670000000000016
# Please wait while getting temperature teahupoo
# The temperature in teahupoo is 24.670000000000016
# 141
# challapata
# Please wait while getting temperature challapata
# The temperature in challapata is 9.312000000000012
# Please wait while getting temperature challapata
# The temperature in challapata is 9.312000000000012
# 142
# provideniya
# Please wait while getting temperature provideniya
# The temperature in provideniya is 7.411999999999978
# Please wait while getting temperature provideniya
# The temperature in provideniya is 7.411999999999978
# 143
# port elizabeth
# Please wait while getting temperature port elizabeth
# The temperature in port elizabeth is 25.279999999999973
# Please wait while getting temperature port elizabeth
# The temperature in port elizabeth is 25.279999999999973
# 144
# castro
# Please wait while getting temperature castro
# The temperature in castro is 10.149999999999977
# Please wait while getting temperature castro
# The temperature in castro is 10.149999999999977
# 145
# taolanaro
# taolanaro is not available
# Please wait while getting temperature taolanaro
# The temperature in taolanaro is 10.149999999999977
# 146
# cockburn town
# Please wait while getting temperature cockburn town
# The temperature in cockburn town is 32.14999999999998
# Please wait while getting temperature cockburn town
# The temperature in cockburn town is 32.14999999999998
# 147
# kisangani
# Please wait while getting temperature kisangani
# The temperature in kisangani is 23.512
# Please wait while getting temperature kisangani
# The temperature in kisangani is 23.512
# 148
# faanui
# Please wait while getting temperature faanui
# The temperature in faanui is 23.71199999999999
# Please wait while getting temperature faanui
# The temperature in faanui is 23.71199999999999
# 149
# mizan teferi
# Please wait while getting temperature mizan teferi
# The temperature in mizan teferi is 17.21199999999999
# Please wait while getting temperature mizan teferi
# The temperature in mizan teferi is 17.21199999999999
# 150
# iqaluit
# Please wait while getting temperature iqaluit
# The temperature in iqaluit is 6.980000000000018
# Please wait while getting temperature iqaluit
# The temperature in iqaluit is 6.980000000000018
# 151
# san patricio
# Please wait while getting temperature san patricio
# The temperature in san patricio is 32.81200000000001
# Please wait while getting temperature san patricio
# The temperature in san patricio is 32.81200000000001
# 152
# chokurdakh
# Please wait while getting temperature chokurdakh
# The temperature in chokurdakh is 5.911999999999978
# Please wait while getting temperature chokurdakh
# The temperature in chokurdakh is 5.911999999999978
# 153
# hermanus
# Please wait while getting temperature hermanus
# The temperature in hermanus is 17.930000000000007
# Please wait while getting temperature hermanus
# The temperature in hermanus is 17.930000000000007
# 154
# port alfred
# Please wait while getting temperature port alfred
# The temperature in port alfred is 16.25999999999999
# Please wait while getting temperature port alfred
# The temperature in port alfred is 16.25999999999999
# 155
# narsaq
# Please wait while getting temperature narsaq
# The temperature in narsaq is 11.149999999999977
# Please wait while getting temperature narsaq
# The temperature in narsaq is 11.149999999999977
# 156
# ancud
# Please wait while getting temperature ancud
# The temperature in ancud is 10.149999999999977
# Please wait while getting temperature ancud
# The temperature in ancud is 10.149999999999977
# 157
# apatou
# Please wait while getting temperature apatou
# The temperature in apatou is 33.21199999999999
# Please wait while getting temperature apatou
# The temperature in apatou is 33.21199999999999
# 158
# georgetown
# Please wait while getting temperature georgetown
# The temperature in georgetown is 32.22000000000003
# Please wait while getting temperature georgetown
# The temperature in georgetown is 32.22000000000003
# 159
# mandera
# Please wait while getting temperature mandera
# The temperature in mandera is 29.612000000000023
# Please wait while getting temperature mandera
# The temperature in mandera is 29.612000000000023
# 160
# sungurlu
# Please wait while getting temperature sungurlu
# The temperature in sungurlu is 21.612000000000023
# Please wait while getting temperature sungurlu
# The temperature in sungurlu is 21.612000000000023
# 161
# abalak
# Please wait while getting temperature abalak
# The temperature in abalak is 29.612000000000023
# Please wait while getting temperature abalak
# The temperature in abalak is 29.612000000000023
# 162
# meulaboh
# Please wait while getting temperature meulaboh
# The temperature in meulaboh is 28.512
# Please wait while getting temperature meulaboh
# The temperature in meulaboh is 28.512
# 163
# general pico
# Please wait while getting temperature general pico
# The temperature in general pico is 17.512
# Please wait while getting temperature general pico
# The temperature in general pico is 17.512
# 164
# matara
# Please wait while getting temperature matara
# The temperature in matara is 13.312000000000012
# Please wait while getting temperature matara
# The temperature in matara is 13.312000000000012
# 165
# kiboga
# Please wait while getting temperature kiboga
# The temperature in kiboga is 18.112000000000023
# Please wait while getting temperature kiboga
# The temperature in kiboga is 18.112000000000023
# 166
# romny
# Please wait while getting temperature romny
# The temperature in romny is 18.411999999999978
# Please wait while getting temperature romny
# The temperature in romny is 18.411999999999978
# 167
# santa fe
# Please wait while getting temperature santa fe
# The temperature in santa fe is 21.100000000000023
# Please wait while getting temperature santa fe
# The temperature in santa fe is 21.100000000000023
# 168
# venice
# Please wait while getting temperature venice
# The temperature in venice is 32.06
# Please wait while getting temperature venice
# The temperature in venice is 32.06
# 169
# guerrero negro
# Please wait while getting temperature guerrero negro
# The temperature in guerrero negro is 21.911999999999978
# Please wait while getting temperature guerrero negro
# The temperature in guerrero negro is 21.911999999999978
# 170
# touros
# Please wait while getting temperature touros
# The temperature in touros is 27.149999999999977
# Please wait while getting temperature touros
# The temperature in touros is 27.149999999999977
# 171
# karamay
# karamay is not available
# Please wait while getting temperature karamay
# The temperature in karamay is 27.149999999999977
# 172
# putla
# putla is not available
# Please wait while getting temperature putla
# The temperature in putla is 27.149999999999977
# 173
# ubrique
# Please wait while getting temperature ubrique
# The temperature in ubrique is 29.00999999999999
# Please wait while getting temperature ubrique
# The temperature in ubrique is 29.00999999999999
# 174
# vila velha
# Please wait while getting temperature vila velha
# The temperature in vila velha is 28.379999999999995
# Please wait while getting temperature vila velha
# The temperature in vila velha is 28.379999999999995
# 175
# hamilton
# Please wait while getting temperature hamilton
# The temperature in hamilton is 20.769999999999982
# Please wait while getting temperature hamilton
# The temperature in hamilton is 20.769999999999982
# 176
# camapua
# Please wait while getting temperature camapua
# The temperature in camapua is 37.81200000000001
# Please wait while getting temperature camapua
# The temperature in camapua is 37.81200000000001
# 177
# mokrousovo
# Please wait while getting temperature mokrousovo
# The temperature in mokrousovo is 10.312000000000012
# Please wait while getting temperature mokrousovo
# The temperature in mokrousovo is 10.312000000000012
# 178
# paamiut
# Please wait while getting temperature paamiut
# The temperature in paamiut is 5.312000000000012
# Please wait while getting temperature paamiut
# The temperature in paamiut is 5.312000000000012
# 179
# danville
# Please wait while getting temperature danville
# The temperature in danville is 18.220000000000027
# Please wait while getting temperature danville
# The temperature in danville is 18.220000000000027
# 180
# severo-kurilsk
# Please wait while getting temperature severo-kurilsk
# The temperature in severo-kurilsk is 10.812000000000012
# Please wait while getting temperature severo-kurilsk
# The temperature in severo-kurilsk is 10.812000000000012
# 181
# bela vista de goias
# Please wait while getting temperature bela vista de goias
# The temperature in bela vista de goias is 32.14999999999998
# Please wait while getting temperature bela vista de goias
# The temperature in bela vista de goias is 32.14999999999998
# 182
# russell
# Please wait while getting temperature russell
# The temperature in russell is 31.930000000000007
# Please wait while getting temperature russell
# The temperature in russell is 31.930000000000007
# 183
# sao filipe
# Please wait while getting temperature sao filipe
# The temperature in sao filipe is 28.012
# Please wait while getting temperature sao filipe
# The temperature in sao filipe is 28.012
# 184
# mizque
# Please wait while getting temperature mizque
# The temperature in mizque is 23.812000000000012
# Please wait while getting temperature mizque
# The temperature in mizque is 23.812000000000012
# 185
# vaitupu
# vaitupu is not available
# Please wait while getting temperature vaitupu
# The temperature in vaitupu is 23.812000000000012
# 186
# hornepayne
# Please wait while getting temperature hornepayne
# The temperature in hornepayne is 13.911999999999978
# Please wait while getting temperature hornepayne
# The temperature in hornepayne is 13.911999999999978
# 187
# taman
# Please wait while getting temperature taman
# The temperature in taman is 17.149999999999977
# Please wait while getting temperature taman
# The temperature in taman is 17.149999999999977
# 188
# saint-augustin
# Please wait while getting temperature saint-augustin
# The temperature in saint-augustin is 19.319999999999993
# Please wait while getting temperature saint-augustin
# The temperature in saint-augustin is 19.319999999999993
# 189
# tiksi
# Please wait while getting temperature tiksi
# The temperature in tiksi is 2.5120000000000005
# Please wait while getting temperature tiksi
# The temperature in tiksi is 2.5120000000000005
# 190
# san francisco
# Please wait while getting temperature san francisco
# The temperature in san francisco is 26.149999999999977
# Please wait while getting temperature san francisco
# The temperature in san francisco is 26.149999999999977
# 191
# fort nelson
# Please wait while getting temperature fort nelson
# The temperature in fort nelson is 10.149999999999977
# Please wait while getting temperature fort nelson
# The temperature in fort nelson is 10.149999999999977
# 192
# tahta
# tahta is not available
# Please wait while getting temperature tahta
# The temperature in tahta is 10.149999999999977
# 193
# yatou
# Please wait while getting temperature yatou
# The temperature in yatou is 26.149999999999977
# Please wait while getting temperature yatou
# The temperature in yatou is 26.149999999999977
# 194
# avera
# Please wait while getting temperature avera
# The temperature in avera is 34.80000000000001
# Please wait while getting temperature avera
# The temperature in avera is 34.80000000000001
# 195
# kawalu
# Please wait while getting temperature kawalu
# The temperature in kawalu is 19.312000000000012
# Please wait while getting temperature kawalu
# The temperature in kawalu is 19.312000000000012
# 196
# vardo
# Please wait while getting temperature vardo
# The temperature in vardo is 25.980000000000018
# Please wait while getting temperature vardo
# The temperature in vardo is 25.980000000000018
# 197
# chuy
# Please wait while getting temperature chuy
# The temperature in chuy is 16.112000000000023
# Please wait while getting temperature chuy
# The temperature in chuy is 16.112000000000023
# 198
# alvand
# Please wait while getting temperature alvand
# The temperature in alvand is 13.612000000000023
# Please wait while getting temperature alvand
# The temperature in alvand is 13.612000000000023
# 199
# mithimna
# mithimna is not available
# Please wait while getting temperature mithimna
# The temperature in mithimna is 13.612000000000023
# 200
# grindavik
# Please wait while getting temperature grindavik
# The temperature in grindavik is 11.680000000000007
# Please wait while getting temperature grindavik
# The temperature in grindavik is 11.680000000000007
# 201
# cap malheureux
# Please wait while getting temperature cap malheureux
# The temperature in cap malheureux is 22.55000000000001
# Please wait while getting temperature cap malheureux
# The temperature in cap malheureux is 22.55000000000001
# 202
# anadyr
# Please wait while getting temperature anadyr
# The temperature in anadyr is 8.04000000000002
# Please wait while getting temperature anadyr
# The temperature in anadyr is 8.04000000000002
# 203
# bredasdorp
# Please wait while getting temperature bredasdorp
# The temperature in bredasdorp is 16.819999999999993
# Please wait while getting temperature bredasdorp
# The temperature in bredasdorp is 16.819999999999993
# 204
# norman wells
# Please wait while getting temperature norman wells
# The temperature in norman wells is 12.149999999999977
# Please wait while getting temperature norman wells
# The temperature in norman wells is 12.149999999999977
# 205
# comodoro rivadavia
# Please wait while getting temperature comodoro rivadavia
# The temperature in comodoro rivadavia is 11.149999999999977
# Please wait while getting temperature comodoro rivadavia
# The temperature in comodoro rivadavia is 11.149999999999977
# 206
# bubaque
# Please wait while getting temperature bubaque
# The temperature in bubaque is 26.411999999999978
# Please wait while getting temperature bubaque
# The temperature in bubaque is 26.411999999999978
# 207
# howard springs
# Please wait while getting temperature howard springs
# The temperature in howard springs is 20.810000000000002
# Please wait while getting temperature howard springs
# The temperature in howard springs is 20.810000000000002
# 208
# banda aceh
# Please wait while getting temperature banda aceh
# The temperature in banda aceh is 28.612000000000023
# Please wait while getting temperature banda aceh
# The temperature in banda aceh is 28.612000000000023
# 209
# baruun-urt
# Please wait while getting temperature baruun-urt
# The temperature in baruun-urt is 6.711999999999989
# Please wait while getting temperature baruun-urt
# The temperature in baruun-urt is 6.711999999999989
# 210
# kandrian
# Please wait while getting temperature kandrian
# The temperature in kandrian is 21.512
# Please wait while getting temperature kandrian
# The temperature in kandrian is 21.512
# 211
# hammel
# Please wait while getting temperature hammel
# The temperature in hammel is 12.050000000000011
# Please wait while getting temperature hammel
# The temperature in hammel is 12.050000000000011
# 212
# los llanos de aridane
# Please wait while getting temperature los llanos de aridane
# The temperature in los llanos de aridane is 22.139999999999986
# Please wait while getting temperature los llanos de aridane
# The temperature in los llanos de aridane is 22.139999999999986
# 213
# sayyan
# Please wait while getting temperature sayyan
# The temperature in sayyan is 25.21199999999999
# Please wait while getting temperature sayyan
# The temperature in sayyan is 25.21199999999999
# 214
# luganville
# Please wait while getting temperature luganville
# The temperature in luganville is 20.149999999999977
# Please wait while getting temperature luganville
# The temperature in luganville is 20.149999999999977
# 215
# axim
# Please wait while getting temperature axim
# The temperature in axim is 25.112000000000023
# Please wait while getting temperature axim
# The temperature in axim is 25.112000000000023
# 216
# olafsvik
# olafsvik is not available
# Please wait while getting temperature olafsvik
# The temperature in olafsvik is 25.112000000000023
# 217
# teguise
# Please wait while getting temperature teguise
# The temperature in teguise is 25.149999999999977
# Please wait while getting temperature teguise
# The temperature in teguise is 25.149999999999977
# 218
# ixtapa
# Please wait while getting temperature ixtapa
# The temperature in ixtapa is 33.04000000000002
# Please wait while getting temperature ixtapa
# The temperature in ixtapa is 33.04000000000002
# 219
# atar
# Please wait while getting temperature atar
# The temperature in atar is 37.14999999999998
# Please wait while getting temperature atar
# The temperature in atar is 37.14999999999998
# 220
# buffalo
# Please wait while getting temperature buffalo
# The temperature in buffalo is 20.00999999999999
# Please wait while getting temperature buffalo
# The temperature in buffalo is 20.00999999999999
# 221
# noumea
# Please wait while getting temperature noumea
# The temperature in noumea is 17.220000000000027
# Please wait while getting temperature noumea
# The temperature in noumea is 17.220000000000027
# 222
# gualaquiza
# Please wait while getting temperature gualaquiza
# The temperature in gualaquiza is 17.911999999999978
# Please wait while getting temperature gualaquiza
# The temperature in gualaquiza is 17.911999999999978
# 223
# nanortalik
# Please wait while getting temperature nanortalik
# The temperature in nanortalik is 6.612000000000023
# Please wait while getting temperature nanortalik
# The temperature in nanortalik is 6.612000000000023
# 224
# amderma
# amderma is not available
# Please wait while getting temperature amderma
# The temperature in amderma is 6.612000000000023
# 225
# merrill
# Please wait while getting temperature merrill
# The temperature in merrill is 22.25
# Please wait while getting temperature merrill
# The temperature in merrill is 22.25
# 226
# esperance
# Please wait while getting temperature esperance
# The temperature in esperance is 8.149999999999977
# Please wait while getting temperature esperance
# The temperature in esperance is 8.149999999999977
# 227
# kushima
# Please wait while getting temperature kushima
# The temperature in kushima is 23.411999999999978
# Please wait while getting temperature kushima
# The temperature in kushima is 23.411999999999978
# 228
# tarrafal
# Please wait while getting temperature tarrafal
# The temperature in tarrafal is 29.149999999999977
# Please wait while getting temperature tarrafal
# The temperature in tarrafal is 29.149999999999977
# 229
# totoral
# Please wait while getting temperature totoral
# The temperature in totoral is 11.149999999999977
# Please wait while getting temperature totoral
# The temperature in totoral is 11.149999999999977
# 230
# san vicente
# Please wait while getting temperature san vicente
# The temperature in san vicente is 23.149999999999977
# Please wait while getting temperature san vicente
# The temperature in san vicente is 23.149999999999977
# 231
# hukuntsi
# Please wait while getting temperature hukuntsi
# The temperature in hukuntsi is 19.21199999999999
# Please wait while getting temperature hukuntsi
# The temperature in hukuntsi is 19.21199999999999
# 232
# port moresby
# Please wait while getting temperature port moresby
# The temperature in port moresby is 23.612000000000023
# Please wait while getting temperature port moresby
# The temperature in port moresby is 23.612000000000023
# 233
# klyuchi
# Please wait while getting temperature klyuchi
# The temperature in klyuchi is 12.911999999999978
# Please wait while getting temperature klyuchi
# The temperature in klyuchi is 12.911999999999978
# 234
# rungata
# rungata is not available
# Please wait while getting temperature rungata
# The temperature in rungata is 12.911999999999978
# 235
# malpe
# Please wait while getting temperature malpe
# The temperature in malpe is 25.149999999999977
# Please wait while getting temperature malpe
# The temperature in malpe is 25.149999999999977
# 236
# muravlenko
# Please wait while getting temperature muravlenko
# The temperature in muravlenko is 10.812000000000012
# Please wait while getting temperature muravlenko
# The temperature in muravlenko is 10.812000000000012
# 237
# zuya
# Please wait while getting temperature zuya
# The temperature in zuya is 18.312000000000012
# Please wait while getting temperature zuya
# The temperature in zuya is 18.312000000000012
# 238
# mersing
# Please wait while getting temperature mersing
# The temperature in mersing is 22.911999999999978
# Please wait while getting temperature mersing
# The temperature in mersing is 22.911999999999978
# 239
# gizo
# Please wait while getting temperature gizo
# The temperature in gizo is 25.420000000000016
# Please wait while getting temperature gizo
# The temperature in gizo is 25.420000000000016
# 240
# dana point
# Please wait while getting temperature dana point
# The temperature in dana point is 29.25
# Please wait while getting temperature dana point
# The temperature in dana point is 29.25
# 241
# ipixuna
# Please wait while getting temperature ipixuna
# The temperature in ipixuna is 30.149999999999977
# Please wait while getting temperature ipixuna
# The temperature in ipixuna is 30.149999999999977
# 242
# korla
# korla is not available
# Please wait while getting temperature korla
# The temperature in korla is 30.149999999999977
# 243
# vostok
# Please wait while getting temperature vostok
# The temperature in vostok is 17.411999999999978
# Please wait while getting temperature vostok
# The temperature in vostok is 17.411999999999978
# 244
# simpang
# Please wait while getting temperature simpang
# The temperature in simpang is 23.612000000000023
# Please wait while getting temperature simpang
# The temperature in simpang is 23.612000000000023
# 245
# pevek
# Please wait while getting temperature pevek
# The temperature in pevek is 3.312000000000012
# Please wait while getting temperature pevek
# The temperature in pevek is 3.312000000000012
# 246
# forestville
# Please wait while getting temperature forestville
# The temperature in forestville is 9.149999999999977
# Please wait while getting temperature forestville
# The temperature in forestville is 9.149999999999977
# 247
# ulladulla
# Please wait while getting temperature ulladulla
# The temperature in ulladulla is 7.560000000000002
# Please wait while getting temperature ulladulla
# The temperature in ulladulla is 7.560000000000002
# 248
# dawlatabad
# Please wait while getting temperature dawlatabad
# The temperature in dawlatabad is 16.411999999999978
# Please wait while getting temperature dawlatabad
# The temperature in dawlatabad is 16.411999999999978
# 249
# parit buntar
# Please wait while getting temperature parit buntar
# The temperature in parit buntar is 26.95999999999998
# Please wait while getting temperature parit buntar
# The temperature in parit buntar is 26.95999999999998
# 250
# najran
# Please wait while getting temperature najran
# The temperature in najran is 34.14999999999998
# Please wait while getting temperature najran
# The temperature in najran is 34.14999999999998
# 251
# arcata
# Please wait while getting temperature arcata
# The temperature in arcata is 17.54000000000002
# Please wait while getting temperature arcata
# The temperature in arcata is 17.54000000000002
# 252
# muriwai beach
# Please wait while getting temperature muriwai beach
# The temperature in muriwai beach is 11.949999999999989
# Please wait while getting temperature muriwai beach
# The temperature in muriwai beach is 11.949999999999989
# 253
# alamosa
# Please wait while getting temperature alamosa
# The temperature in alamosa is 21.79000000000002
# Please wait while getting temperature alamosa
# The temperature in alamosa is 21.79000000000002
# 254
# marcona
# marcona is not available
# Please wait while getting temperature marcona
# The temperature in marcona is 21.79000000000002
# 255
# vlore
# Please wait while getting temperature vlore
# The temperature in vlore is 25.812000000000012
# Please wait while getting temperature vlore
# The temperature in vlore is 25.812000000000012
# 256
# forio
# Please wait while getting temperature forio
# The temperature in forio is 23.920000000000016
# Please wait while getting temperature forio
# The temperature in forio is 23.920000000000016
# 257
# kapaa
# Please wait while getting temperature kapaa
# The temperature in kapaa is 27.629999999999995
# Please wait while getting temperature kapaa
# The temperature in kapaa is 27.629999999999995
# 258
# flinders
# Please wait while getting temperature flinders
# The temperature in flinders is 11.560000000000002
# Please wait while getting temperature flinders
# The temperature in flinders is 11.560000000000002
# 259
# kuryk
# Please wait while getting temperature kuryk
# The temperature in kuryk is 19.512
# Please wait while getting temperature kuryk
# The temperature in kuryk is 19.512
# 260
# salalah
# Please wait while getting temperature salalah
# The temperature in salalah is 26.149999999999977
# Please wait while getting temperature salalah
# The temperature in salalah is 26.149999999999977
# 261
# sept-iles
# Please wait while getting temperature sept-iles
# The temperature in sept-iles is 13.189999999999998
# Please wait while getting temperature sept-iles
# The temperature in sept-iles is 13.189999999999998
# 262
# lasa
# Please wait while getting temperature lasa
# The temperature in lasa is 25.45999999999998
# Please wait while getting temperature lasa
# The temperature in lasa is 25.45999999999998
# 263
# olhao
# Please wait while getting temperature olhao
# The temperature in olhao is 25.94999999999999
# Please wait while getting temperature olhao
# The temperature in olhao is 25.94999999999999
# 264
# oussouye
# Please wait while getting temperature oussouye
# The temperature in oussouye is 28.149999999999977
# Please wait while getting temperature oussouye
# The temperature in oussouye is 28.149999999999977
# 265
# maryborough
# Please wait while getting temperature maryborough
# The temperature in maryborough is 10.612000000000023
# Please wait while getting temperature maryborough
# The temperature in maryborough is 10.612000000000023
# 266
# cherskiy
# Please wait while getting temperature cherskiy
# The temperature in cherskiy is 3.312000000000012
# Please wait while getting temperature cherskiy
# The temperature in cherskiy is 3.312000000000012
# 267
# mehamn
# Please wait while getting temperature mehamn
# The temperature in mehamn is 6.411999999999978
# Please wait while getting temperature mehamn
# The temperature in mehamn is 6.411999999999978
# 268
# pitimbu
# Please wait while getting temperature pitimbu
# The temperature in pitimbu is 26.149999999999977
# Please wait while getting temperature pitimbu
# The temperature in pitimbu is 26.149999999999977
# 269
# zhicheng
# Please wait while getting temperature zhicheng
# The temperature in zhicheng is 24.112000000000023
# Please wait while getting temperature zhicheng
# The temperature in zhicheng is 24.112000000000023
# 270
# yuma
# Please wait while getting temperature yuma
# The temperature in yuma is 37.69999999999999
# Please wait while getting temperature yuma
# The temperature in yuma is 37.69999999999999
# 271
# nantucket
# Please wait while getting temperature nantucket
# The temperature in nantucket is 16.810000000000002
# Please wait while getting temperature nantucket
# The temperature in nantucket is 16.810000000000002
# 272
# benguela
# Please wait while getting temperature benguela
# The temperature in benguela is 21.411999999999978
# Please wait while getting temperature benguela
# The temperature in benguela is 21.411999999999978
# 273
# lokomotivnyy
# Please wait while getting temperature lokomotivnyy
# The temperature in lokomotivnyy is 10.312000000000012
# Please wait while getting temperature lokomotivnyy
# The temperature in lokomotivnyy is 10.312000000000012
# 274
# rosario
# Please wait while getting temperature rosario
# The temperature in rosario is 15.930000000000007
# Please wait while getting temperature rosario
# The temperature in rosario is 15.930000000000007
# 275
# nouakchott
# Please wait while getting temperature nouakchott
# The temperature in nouakchott is 31.149999999999977
# Please wait while getting temperature nouakchott
# The temperature in nouakchott is 31.149999999999977
# 276
# havelock
# Please wait while getting temperature havelock
# The temperature in havelock is 31.329999999999984
# Please wait while getting temperature havelock
# The temperature in havelock is 31.329999999999984
# 277
# akureyri

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
