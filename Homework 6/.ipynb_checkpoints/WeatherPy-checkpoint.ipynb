# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
city="Cleveland"
temp = "temperature"
humidity = "humidity"
cloudiness = "cloudiness"
wind_speed = "wind speed"
lat = "latitude"
long = "longtitude"

base_url = f"http://api.openweathermap.org/data/2.5/weather?"
weather_url = f"{base_url}&appid={api_key}&q="
print(weather_url)


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# http://api.openweathermap.org/data/2.5/weather?&appid=05f76755e25994576b9841c3f991db18&q=

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_response = requests.get(weather_url)
weather_json = weather_response.json()
#cities = [len]
weather = pd.DataFrame(columns=["City Name", "Temperature", "Humidity", "Cloudiness", "Wind Speed", "Latitude", "Longitiude"])
weather
for i, city in enumerate (cities): 
    print(i)
    print(city)
    weather.loc[i, "City Name"] = city
    
    response = requests.get(weather_url + city)
    #response = requests.get(weather_url + temp)
    #print(response.url)
    response = response.json()
    
    #print(response)
    try: 
         
        temp = response["main"]["temp"] - 273
        print(f"The temperature in {city} is {temp}")
    except Exception as e:
        print(f" temp is not available")
        
    try:
        humidity = response["main"]["humidity"]
        print(f"The humidity in {city} is {humidity}")
    except Exception as e:
        print(f" humidity is not available")
    
    try:    
        cloudiness = response["clouds"]["all"]
        print(f"The cloudiness in {city} is {cloudiness}")
    except Exception as e: 
        print(f" cloudiness is not available")
        
    try:
        wind_speed = response["wind"]["speed"]
        print(f"The windspeed in {city} is {wind_speed}")
    except Exception as e:
        print(f" wind_speed is not available")
    
    try:    
        lat = response["coord"]["lat"]
        print(f"The coordinates for {city} is {lat}")
    except Exception as e:
         print(f" lat is not available")
    
    try:    
        long = response["coord"]["lon"]
        print(f"The coordinates for {city} is {long}")
    except Exception as e:
        print(f" long is not available")
        
        #print(f"Please wait while getting temperature for {city}")
              

    #print(f"The temperature in {city} is {temp}")
    weather.loc[i, "Temperature"] = temp
    weather.loc[i, "City Name"] = city
    weather.loc[i, "Humidity"] = humidity
    weather.loc[i, "Cloudiness"] = cloudiness
    weather.loc[i, "Wind Speed"] = wind_speed
    weather.loc[i, "Latitude"] = lat
    weather.loc[i, "Longititude"] = long

weather
# Out:
# 0
# tura
# The temperature in tura is 7.406000000000006
# The humidity in tura is 59
# The cloudiness in tura is 74
# The windspeed in tura is 4.55
# The coordinates for tura is 64.27
# The coordinates for tura is 100.22
# 1
# mataura
# The temperature in mataura is 10.149999999999977
# The humidity in mataura is 71
# The cloudiness in mataura is 98
# The windspeed in mataura is 5.36
# The coordinates for mataura is -46.19
# The coordinates for mataura is 168.86
# 2
# nelson bay
# The temperature in nelson bay is 17.75
# The humidity in nelson bay is 59
# The cloudiness in nelson bay is 75
# The windspeed in nelson bay is 6.2
# The coordinates for nelson bay is -32.72
# The coordinates for nelson bay is 152.14
# 3
# airai
# The temperature in airai is 28.805999999999983
# The humidity in airai is 37
# The cloudiness in airai is 61
# The windspeed in airai is 0.99
# The coordinates for airai is -8.93
# The coordinates for airai is 125.41
# 4
# xiamen
# The temperature in xiamen is 31.149999999999977
# The humidity in xiamen is 62
# The cloudiness in xiamen is 40
# The windspeed in xiamen is 1
# The coordinates for xiamen is 24.46
# The coordinates for xiamen is 118.07
# 5
# tasiilaq
# The temperature in tasiilaq is 4.149999999999977
# The humidity in tasiilaq is 80
# The cloudiness in tasiilaq is 0
# The windspeed in tasiilaq is 2.6
# The coordinates for tasiilaq is 65.61
# The coordinates for tasiilaq is -37.64
# 6
# taolanaro
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 7
# ushuaia
# The temperature in ushuaia is 6.149999999999977
# The humidity in ushuaia is 70
# The cloudiness in ushuaia is 75
# The windspeed in ushuaia is 1.5
# The coordinates for ushuaia is -54.81
# The coordinates for ushuaia is -68.31
# 8
# rocha
# The temperature in rocha is 9.605999999999995
# The humidity in rocha is 91
# The cloudiness in rocha is 100
# The windspeed in rocha is 1.75
# The coordinates for rocha is -34.48
# The coordinates for rocha is -54.34
# 9
# syamzha
# The temperature in syamzha is 12.206000000000017
# The humidity in syamzha is 97
# The cloudiness in syamzha is 2
# The windspeed in syamzha is 2.1
# The coordinates for syamzha is 60.02
# The coordinates for syamzha is 41.06
# 10
# kirakira
# The temperature in kirakira is 26.406000000000006
# The humidity in kirakira is 88
# The cloudiness in kirakira is 100
# The windspeed in kirakira is 8.56
# The coordinates for kirakira is -10.46
# The coordinates for kirakira is 161.92
# 11
# hithadhoo
# The temperature in hithadhoo is 29.005999999999972
# The humidity in hithadhoo is 68
# The cloudiness in hithadhoo is 37
# The windspeed in hithadhoo is 2.93
# The coordinates for hithadhoo is -0.6
# The coordinates for hithadhoo is 73.08
# 12
# albany
# The temperature in albany is 20.329999999999984
# The humidity in albany is 69
# The cloudiness in albany is 75
# The windspeed in albany is 5.1
# The coordinates for albany is 42.65
# The coordinates for albany is -73.75
# 13
# punta arenas
# The temperature in punta arenas is 6.4599999999999795
# The humidity in punta arenas is 75
# The cloudiness in punta arenas is 40
# The windspeed in punta arenas is 8.2
# The coordinates for punta arenas is -53.16
# The coordinates for punta arenas is -70.91
# 14
# prior lake
# The temperature in prior lake is 18.939999999999998
# The humidity in prior lake is 88
# The cloudiness in prior lake is 1
# The windspeed in prior lake is 2.54
# The coordinates for prior lake is 44.71
# The coordinates for prior lake is -93.42
# 15
# dong hoi
# The temperature in dong hoi is 30.706000000000017
# The humidity in dong hoi is 61
# The cloudiness in dong hoi is 88
# The windspeed in dong hoi is 1.62
# The coordinates for dong hoi is 17.48
# The coordinates for dong hoi is 106.6
# 16
# nanortalik
# The temperature in nanortalik is 4.1059999999999945
# The humidity in nanortalik is 88
# The cloudiness in nanortalik is 100
# The windspeed in nanortalik is 2.1
# The coordinates for nanortalik is 60.14
# The coordinates for nanortalik is -45.24
# 17
# urumqi
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 18
# ponta do sol
# The temperature in ponta do sol is 22.105999999999995
# The humidity in ponta do sol is 40
# The cloudiness in ponta do sol is 78
# The windspeed in ponta do sol is 1.59
# The coordinates for ponta do sol is -20.63
# The coordinates for ponta do sol is -46
# 19
# rikitea
# The temperature in rikitea is 22.505999999999972
# The humidity in rikitea is 81
# The cloudiness in rikitea is 49
# The windspeed in rikitea is 7.75
# The coordinates for rikitea is -23.12
# The coordinates for rikitea is -134.97
# 20
# saskylakh
# The temperature in saskylakh is 4.005999999999972
# The humidity in saskylakh is 88
# The cloudiness in saskylakh is 100
# The windspeed in saskylakh is 5.93
# The coordinates for saskylakh is 71.97
# The coordinates for saskylakh is 114.09
# 21
# meyungs
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 22
# kaitangata
# The temperature in kaitangata is 8.805999999999983
# The humidity in kaitangata is 60
# The cloudiness in kaitangata is 91
# The windspeed in kaitangata is 5.07
# The coordinates for kaitangata is -46.28
# The coordinates for kaitangata is 169.85
# 23
# hermanus
# The temperature in hermanus is 14.04000000000002
# The humidity in hermanus is 84
# The cloudiness in hermanus is 34
# The windspeed in hermanus is 0.45
# The coordinates for hermanus is -34.42
# The coordinates for hermanus is 19.24
# 24
# progreso
# The temperature in progreso is 9.45999999999998
# The humidity in progreso is 87
# The cloudiness in progreso is 20
# The windspeed in progreso is 2.1
# The coordinates for progreso is -34.68
# The coordinates for progreso is -56.22
# 25
# marcona
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 26
# estelle
# The temperature in estelle is 18.149999999999977
# The humidity in estelle is 63
# The cloudiness in estelle is 0
# The windspeed in estelle is 4.1
# The coordinates for estelle is 43.97
# The coordinates for estelle is 3.47
# 27
# bonthe
# The temperature in bonthe is 23.906000000000006
# The humidity in bonthe is 94
# The cloudiness in bonthe is 100
# The windspeed in bonthe is 3.09
# The coordinates for bonthe is 7.53
# The coordinates for bonthe is -12.5
# 28
# atuona
# The temperature in atuona is 26.706000000000017
# The humidity in atuona is 73
# The cloudiness in atuona is 76
# The windspeed in atuona is 7.34
# The coordinates for atuona is -9.8
# The coordinates for atuona is -139.03
# 29
# wajima
# The temperature in wajima is 28.149999999999977
# The humidity in wajima is 78
# The cloudiness in wajima is 75
# The windspeed in wajima is 4.6
# The coordinates for wajima is 37.4
# The coordinates for wajima is 136.9
# 30
# mar del plata
# The temperature in mar del plata is 4.505999999999972
# The humidity in mar del plata is 52
# The cloudiness in mar del plata is 0
# The windspeed in mar del plata is 3.4
# The coordinates for mar del plata is -46.43
# The coordinates for mar del plata is -67.52
# 31
# kapaa
# The temperature in kapaa is 30.029999999999973
# The humidity in kapaa is 62
# The cloudiness in kapaa is 20
# The windspeed in kapaa is 9.8
# The coordinates for kapaa is 22.08
# The coordinates for kapaa is -159.32
# 32
# cidreira
# The temperature in cidreira is 15.906000000000006
# The humidity in cidreira is 91
# The cloudiness in cidreira is 34
# The windspeed in cidreira is 3.57
# The coordinates for cidreira is -30.17
# The coordinates for cidreira is -50.22
# 33
# kamalganj
# The temperature in kamalganj is 26.706000000000017
# The humidity in kamalganj is 91
# The cloudiness in kamalganj is 100
# The windspeed in kamalganj is 1.76
# The coordinates for kamalganj is 24.35
# The coordinates for kamalganj is 91.86
# 34
# hobart
# The temperature in hobart is 17.94999999999999
# The humidity in hobart is 45
# The cloudiness in hobart is 0
# The windspeed in hobart is 8.2
# The coordinates for hobart is -42.88
# The coordinates for hobart is 147.33
# 35
# daxian
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 36
# kalmunai
# The temperature in kalmunai is 29.605999999999995
# The humidity in kalmunai is 65
# The cloudiness in kalmunai is 100
# The windspeed in kalmunai is 1.52
# The coordinates for kalmunai is 7.42
# The coordinates for kalmunai is 81.82
# 37
# arvika
# The temperature in arvika is 13.160000000000025
# The humidity in arvika is 93
# The cloudiness in arvika is 50
# The windspeed in arvika is 2.6
# The coordinates for arvika is 59.65
# The coordinates for arvika is 12.59
# 38
# sitka
# The temperature in sitka is 26.55000000000001
# The humidity in sitka is 59
# The cloudiness in sitka is 0
# The windspeed in sitka is 6.71
# The coordinates for sitka is 37.17
# The coordinates for sitka is -99.65
# 39
# kendari
# The temperature in kendari is 31.206000000000017
# The humidity in kendari is 43
# The cloudiness in kendari is 33
# The windspeed in kendari is 1.79
# The coordinates for kendari is -3.99
# The coordinates for kendari is 122.52
# 40
# qaqortoq
# The temperature in qaqortoq is 6.149999999999977
# The humidity in qaqortoq is 55
# The cloudiness in qaqortoq is 100
# The windspeed in qaqortoq is 5.7
# The coordinates for qaqortoq is 60.72
# The coordinates for qaqortoq is -46.03
# 41
# cape town
# The temperature in cape town is 14.29000000000002
# The humidity in cape town is 76
# The cloudiness in cape town is 20
# The windspeed in cape town is 3.1
# The coordinates for cape town is -33.93
# The coordinates for cape town is 18.42
# 42
# babanusah
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 43
# port hedland
# The temperature in port hedland is 31.149999999999977
# The humidity in port hedland is 10
# The cloudiness in port hedland is 38
# The windspeed in port hedland is 7.7
# The coordinates for port hedland is -20.31
# The coordinates for port hedland is 118.58
# 44
# victoria
# The temperature in victoria is 27.629999999999995
# The humidity in victoria is 83
# The cloudiness in victoria is 75
# The windspeed in victoria is 1
# The coordinates for victoria is 5.28
# The coordinates for victoria is 115.24
# 45
# hilo
# The temperature in hilo is 28.110000000000014
# The humidity in hilo is 58
# The cloudiness in hilo is 1
# The windspeed in hilo is 4.6
# The coordinates for hilo is 19.71
# The coordinates for hilo is -155.08
# 46
# sechura
# The temperature in sechura is 16.605999999999995
# The humidity in sechura is 86
# The cloudiness in sechura is 0
# The windspeed in sechura is 5.94
# The coordinates for sechura is -5.56
# The coordinates for sechura is -80.82
# 47
# la asuncion
# The temperature in la asuncion is 6.206000000000017
# The humidity in la asuncion is 96
# The cloudiness in la asuncion is 100
# The windspeed in la asuncion is 1.24
# The coordinates for la asuncion is -26.05
# The coordinates for la asuncion is -65.39
# 48
# mullaitivu
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 49
# mezen
# The temperature in mezen is 11.005999999999972
# The humidity in mezen is 88
# The cloudiness in mezen is 84
# The windspeed in mezen is 2.59
# The coordinates for mezen is 65.85
# The coordinates for mezen is 44.24
# 50
# mount gambier
# The temperature in mount gambier is 15.149999999999977
# The humidity in mount gambier is 58
# The cloudiness in mount gambier is 66
# The windspeed in mount gambier is 4.1
# The coordinates for mount gambier is -37.83
# The coordinates for mount gambier is 140.78
# 51
# kavaratti
# The temperature in kavaratti is 28.005999999999972
# The humidity in kavaratti is 78
# The cloudiness in kavaratti is 100
# The windspeed in kavaratti is 7.69
# The coordinates for kavaratti is 10.57
# The coordinates for kavaratti is 72.64
# 52
# new norfolk
# The temperature in new norfolk is 18.720000000000027
# The humidity in new norfolk is 45
# The cloudiness in new norfolk is 0
# The windspeed in new norfolk is 8.2
# The coordinates for new norfolk is -42.78
# The coordinates for new norfolk is 147.06
# 53
# asau
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 54
# jamestown
# The temperature in jamestown is 21.305999999999983
# The humidity in jamestown is 36
# The cloudiness in jamestown is 0
# The windspeed in jamestown is 4.23
# The coordinates for jamestown is -33.21
# The coordinates for jamestown is 138.6
# 55
# dera bugti
# The temperature in dera bugti is 32.406000000000006
# The humidity in dera bugti is 32
# The cloudiness in dera bugti is 20
# The windspeed in dera bugti is 1.06
# The coordinates for dera bugti is 29.03
# The coordinates for dera bugti is 69.15
# 56
# gornopravdinsk
# The temperature in gornopravdinsk is 5.206000000000017
# The humidity in gornopravdinsk is 86
# The cloudiness in gornopravdinsk is 0
# The windspeed in gornopravdinsk is 4.02
# The coordinates for gornopravdinsk is 60.06
# The coordinates for gornopravdinsk is 69.92
# 57
# puerto ayora
# The temperature in puerto ayora is 19.589999999999975
# The humidity in puerto ayora is 88
# The cloudiness in puerto ayora is 62
# The windspeed in puerto ayora is 1.34
# The coordinates for puerto ayora is -0.74
# The coordinates for puerto ayora is -90.35
# 58
# amderma
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 59
# tonota
# The temperature in tonota is 13.906000000000006
# The humidity in tonota is 19
# The cloudiness in tonota is 0
# The windspeed in tonota is 1.71
# The coordinates for tonota is -21.44
# The coordinates for tonota is 27.46
# 60
# lorengau
# The temperature in lorengau is 28.105999999999995
# The humidity in lorengau is 64
# The cloudiness in lorengau is 100
# The windspeed in lorengau is 6.73
# The coordinates for lorengau is -2.02
# The coordinates for lorengau is 147.27
# 61
# mahebourg
# The temperature in mahebourg is 18.160000000000025
# The humidity in mahebourg is 88
# The cloudiness in mahebourg is 40
# The windspeed in mahebourg is 3.1
# The coordinates for mahebourg is -20.41
# The coordinates for mahebourg is 57.7
# 62
# palmas
# The temperature in palmas is 24.206000000000017
# The humidity in palmas is 39
# The cloudiness in palmas is 0
# The windspeed in palmas is 0.84
# The coordinates for palmas is -10.18
# The coordinates for palmas is -48.33
# 63
# lebu
# The temperature in lebu is 11.305999999999983
# The humidity in lebu is 88
# The cloudiness in lebu is 98
# The windspeed in lebu is 0.75
# The coordinates for lebu is 8.96
# The coordinates for lebu is 38.73
# 64
# brae
# The temperature in brae is 12.149999999999977
# The humidity in brae is 93
# The cloudiness in brae is 100
# The windspeed in brae is 13.9
# The coordinates for brae is 60.4
# The coordinates for brae is -1.35
# 65
# illoqqortoormiut
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 66
# doha
# The temperature in doha is 30.720000000000027
# The humidity in doha is 66
# The cloudiness in doha is 0
# The windspeed in doha is 3.1
# The coordinates for doha is 25.29
# The coordinates for doha is 51.53
# 67
# tawnat
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 68
# pimentel
# The temperature in pimentel is 23.906000000000006
# The humidity in pimentel is 73
# The cloudiness in pimentel is 38
# The windspeed in pimentel is 1.62
# The coordinates for pimentel is -3.7
# The coordinates for pimentel is -45.5
# 69
# kodiak
# The temperature in kodiak is 25.560000000000002
# The humidity in kodiak is 88
# The cloudiness in kodiak is 1
# The windspeed in kodiak is 4.1
# The coordinates for kodiak is 39.95
# The coordinates for kodiak is -94.76
# 70
# ksenyevka
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 71
# cabo san lucas
# The temperature in cabo san lucas is 27.600000000000023
# The humidity in cabo san lucas is 74
# The cloudiness in cabo san lucas is 5
# The windspeed in cabo san lucas is 2.6
# The coordinates for cabo san lucas is 22.89
# The coordinates for cabo san lucas is -109.91
# 72
# vestmannaeyjar
# The temperature in vestmannaeyjar is 10.305999999999983
# The humidity in vestmannaeyjar is 86
# The cloudiness in vestmannaeyjar is 100
# The windspeed in vestmannaeyjar is 3.2
# The coordinates for vestmannaeyjar is 63.44
# The coordinates for vestmannaeyjar is -20.27
# 73
# longyearbyen
# The temperature in longyearbyen is 8.149999999999977
# The humidity in longyearbyen is 75
# The cloudiness in longyearbyen is 75
# The windspeed in longyearbyen is 7.7
# The coordinates for longyearbyen is 78.22
# The coordinates for longyearbyen is 15.63
# 74
# meulaboh
# The temperature in meulaboh is 26.706000000000017
# The humidity in meulaboh is 79
# The cloudiness in meulaboh is 100
# The windspeed in meulaboh is 3.08
# The coordinates for meulaboh is 4.14
# The coordinates for meulaboh is 96.13
# 75
# vaini
# The temperature in vaini is 21.149999999999977
# The humidity in vaini is 94
# The cloudiness in vaini is 75
# The windspeed in vaini is 3.1
# The coordinates for vaini is 15.34
# The coordinates for vaini is 74.49
# 76
# jalu
# The temperature in jalu is 25.605999999999995
# The humidity in jalu is 40
# The cloudiness in jalu is 0
# The windspeed in jalu is 3.29
# The coordinates for jalu is 29.03
# The coordinates for jalu is 21.55
# 77
# urambo
# The temperature in urambo is 21.505999999999972
# The humidity in urambo is 47
# The cloudiness in urambo is 100
# The windspeed in urambo is 1.34
# The coordinates for urambo is -5.07
# The coordinates for urambo is 32.07
# 78
# venado tuerto
# The temperature in venado tuerto is 10.149999999999977
# The humidity in venado tuerto is 95
# The cloudiness in venado tuerto is 83
# The windspeed in venado tuerto is 0.45
# The coordinates for venado tuerto is -33.75
# The coordinates for venado tuerto is -61.97
# 79
# tuktoyaktuk
# The temperature in tuktoyaktuk is 13.149999999999977
# The humidity in tuktoyaktuk is 82
# The cloudiness in tuktoyaktuk is 75
# The windspeed in tuktoyaktuk is 2.6
# The coordinates for tuktoyaktuk is 69.44
# The coordinates for tuktoyaktuk is -133.03
# 80
# carnarvon
# The temperature in carnarvon is 11.206000000000017
# The humidity in carnarvon is 54
# The cloudiness in carnarvon is 0
# The windspeed in carnarvon is 4.71
# The coordinates for carnarvon is -30.97
# The coordinates for carnarvon is 22.13
# 81
# avarua
# The temperature in avarua is 26.149999999999977
# The humidity in avarua is 74
# The cloudiness in avarua is 92
# The windspeed in avarua is 6.2
# The coordinates for avarua is -21.21
# The coordinates for avarua is -159.78
# 82
# arraial do cabo
# The temperature in arraial do cabo is 21.005999999999972
# The humidity in arraial do cabo is 90
# The cloudiness in arraial do cabo is 100
# The windspeed in arraial do cabo is 6.76
# The coordinates for arraial do cabo is -22.97
# The coordinates for arraial do cabo is -42.02
# 83
# geraldton
# The temperature in geraldton is 7.149999999999977
# The humidity in geraldton is 100
# The cloudiness in geraldton is 90
# The windspeed in geraldton is 6.7
# The coordinates for geraldton is 49.72
# The coordinates for geraldton is -86.95
# 84
# chokurdakh
# The temperature in chokurdakh is 5.1059999999999945
# The humidity in chokurdakh is 59
# The cloudiness in chokurdakh is 3
# The windspeed in chokurdakh is 5.51
# The coordinates for chokurdakh is 70.62
# The coordinates for chokurdakh is 147.9
# 85
# qaanaaq
# The temperature in qaanaaq is -5.3940000000000055
# The humidity in qaanaaq is 58
# The cloudiness in qaanaaq is 0
# The windspeed in qaanaaq is 2.97
# The coordinates for qaanaaq is 77.48
# The coordinates for qaanaaq is -69.36
# 86
# mount darwin
# The temperature in mount darwin is 11.305999999999983
# The humidity in mount darwin is 35
# The cloudiness in mount darwin is 0
# The windspeed in mount darwin is 1.8
# The coordinates for mount darwin is -16.77
# The coordinates for mount darwin is 31.58
# 87
# castro
# The temperature in castro is 2.1499999999999773
# The humidity in castro is 73
# The cloudiness in castro is 0
# The windspeed in castro is 2.6
# The coordinates for castro is -42.48
# The coordinates for castro is -73.76
# 88
# beira
# The temperature in beira is 12.410000000000025
# The humidity in beira is 93
# The cloudiness in beira is 100
# The windspeed in beira is 1.5
# The coordinates for beira is 43.2
# The coordinates for beira is -8.36
# 89
# adrar
# The temperature in adrar is 30.149999999999977
# The humidity in adrar is 20
# The cloudiness in adrar is 0
# The windspeed in adrar is 3.1
# The coordinates for adrar is 27.87
# The coordinates for adrar is -0.29
# 90
# port alfred
# The temperature in port alfred is 19.589999999999975
# The humidity in port alfred is 90
# The cloudiness in port alfred is 100
# The windspeed in port alfred is 2.24
# The coordinates for port alfred is -33.59
# The coordinates for port alfred is 26.89
# 91
# yellowknife
# The temperature in yellowknife is 11.990000000000009
# The humidity in yellowknife is 66
# The cloudiness in yellowknife is 20
# The windspeed in yellowknife is 4.6
# The coordinates for yellowknife is 62.45
# The coordinates for yellowknife is -114.38
# 92
# eyl
# The temperature in eyl is 24.206000000000017
# The humidity in eyl is 74
# The cloudiness in eyl is 0
# The windspeed in eyl is 10.32
# The coordinates for eyl is 7.98
# The coordinates for eyl is 49.82
# 93
# ofunato
# The temperature in ofunato is 19.149999999999977
# The humidity in ofunato is 100
# The cloudiness in ofunato is 75
# The windspeed in ofunato is 3.6
# The coordinates for ofunato is 39.11
# The coordinates for ofunato is 141.75
# 94
# samarai
# The temperature in samarai is 24.505999999999972
# The humidity in samarai is 61
# The cloudiness in samarai is 43
# The windspeed in samarai is 4.88
# The coordinates for samarai is -10.62
# The coordinates for samarai is 150.67
# 95
# paradwip
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 96
# belushya guba
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 97
# dona ines
# The temperature in dona ines is 18.706000000000017
# The humidity in dona ines is 94
# The cloudiness in dona ines is 0
# The windspeed in dona ines is 3.81
# The coordinates for dona ines is -6.62
# The coordinates for dona ines is -35.63
# 98
# solnechnyy
# The temperature in solnechnyy is 18.305999999999983
# The humidity in solnechnyy is 60
# The cloudiness in solnechnyy is 80
# The windspeed in solnechnyy is 0.89
# The coordinates for solnechnyy is 50.72
# The coordinates for solnechnyy is 136.64
# 99
# boshnyakovo
# The temperature in boshnyakovo is 13.406000000000006
# The humidity in boshnyakovo is 81
# The cloudiness in boshnyakovo is 8
# The windspeed in boshnyakovo is 3.73
# The coordinates for boshnyakovo is 49.65
# The coordinates for boshnyakovo is 142.17
# 100
# westport
# The temperature in westport is 20.120000000000005
# The humidity in westport is 78
# The cloudiness in westport is 1
# The windspeed in westport is 3.1
# The coordinates for westport is 41.14
# The coordinates for westport is -73.36
# 101
# ilulissat
# The temperature in ilulissat is 2.1499999999999773
# The humidity in ilulissat is 80
# The cloudiness in ilulissat is 97
# The windspeed in ilulissat is 5.1
# The coordinates for ilulissat is 69.22
# The coordinates for ilulissat is -51.1
# 102
# bengkulu
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 103
# camocim
# The temperature in camocim is 22.005999999999972
# The humidity in camocim is 82
# The cloudiness in camocim is 0
# The windspeed in camocim is 3.04
# The coordinates for camocim is -2.9
# The coordinates for camocim is -40.84
# 104
# savelugu
# The temperature in savelugu is 23.005999999999972
# The humidity in savelugu is 92
# The cloudiness in savelugu is 100
# The windspeed in savelugu is 1.08
# The coordinates for savelugu is 9.63
# The coordinates for savelugu is -0.83
# 105
# touros
# The temperature in touros is 23.149999999999977
# The humidity in touros is 94
# The cloudiness in touros is 20
# The windspeed in touros is 1.5
# The coordinates for touros is -5.2
# The coordinates for touros is -35.46
# 106
# mikun
# The temperature in mikun is 11.005999999999972
# The humidity in mikun is 90
# The cloudiness in mikun is 95
# The windspeed in mikun is 3.23
# The coordinates for mikun is 62.35
# The coordinates for mikun is 50.08
# 107
# necochea
# The temperature in necochea is 6.819999999999993
# The humidity in necochea is 92
# The cloudiness in necochea is 70
# The windspeed in necochea is 0.89
# The coordinates for necochea is -38.55
# The coordinates for necochea is -58.74
# 108
# lompoc
# The temperature in lompoc is 17.779999999999973
# The humidity in lompoc is 93
# The cloudiness in lompoc is 90
# The windspeed in lompoc is 5.7
# The coordinates for lompoc is 34.64
# The coordinates for lompoc is -120.46
# 109
# upernavik
# The temperature in upernavik is 1.6059999999999945
# The humidity in upernavik is 93
# The cloudiness in upernavik is 100
# The windspeed in upernavik is 7.9
# The coordinates for upernavik is 72.79
# The coordinates for upernavik is -56.15
# 110
# senador jose porfirio
# The temperature in senador jose porfirio is 27.206000000000017
# The humidity in senador jose porfirio is 68
# The cloudiness in senador jose porfirio is 2
# The windspeed in senador jose porfirio is 2.36
# The coordinates for senador jose porfirio is -2.59
# The coordinates for senador jose porfirio is -51.95
# 111
# dikson
# The temperature in dikson is 2.6059999999999945
# The humidity in dikson is 67
# The cloudiness in dikson is 87
# The windspeed in dikson is 13.81
# The coordinates for dikson is 73.51
# The coordinates for dikson is 80.55
# 112
# nagato
# The temperature in nagato is 30.730000000000018
# The humidity in nagato is 83
# The cloudiness in nagato is 20
# The windspeed in nagato is 2.6
# The coordinates for nagato is 34.35
# The coordinates for nagato is 131.14
# 113
# attawapiskat
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 114
# karratha
# The temperature in karratha is 35.30599999999998
# The humidity in karratha is 9
# The cloudiness in karratha is 33
# The windspeed in karratha is 8.59
# The coordinates for karratha is -20.74
# The coordinates for karratha is 116.85
# 115
# college
# The temperature in college is 15.610000000000014
# The humidity in college is 51
# The cloudiness in college is 20
# The windspeed in college is 4.1
# The coordinates for college is 64.86
# The coordinates for college is -147.8
# 116
# pacific grove
# The temperature in pacific grove is 18.360000000000014
# The humidity in pacific grove is 68
# The cloudiness in pacific grove is 1
# The windspeed in pacific grove is 7.2
# The coordinates for pacific grove is 36.62
# The coordinates for pacific grove is -121.92
# 117
# dunedin
# The temperature in dunedin is 10.149999999999977
# The humidity in dunedin is 60
# The cloudiness in dunedin is 90
# The windspeed in dunedin is 7.15
# The coordinates for dunedin is -45.87
# The coordinates for dunedin is 170.5
# 118
# sur
# The temperature in sur is 27.706000000000017
# The humidity in sur is 60
# The cloudiness in sur is 96
# The windspeed in sur is 3.21
# The coordinates for sur is 22.57
# The coordinates for sur is 59.53
# 119
# hovd
# The temperature in hovd is 15.470000000000027
# The humidity in hovd is 67
# The cloudiness in hovd is 0
# The windspeed in hovd is 7.2
# The coordinates for hovd is 63.83
# The coordinates for hovd is 10.7
# 120
# busselton
# The temperature in busselton is 19.889999999999986
# The humidity in busselton is 57
# The cloudiness in busselton is 18
# The windspeed in busselton is 7.9
# The coordinates for busselton is -33.64
# The coordinates for busselton is 115.35
# 121
# yaan
# The temperature in yaan is 22.105999999999995
# The humidity in yaan is 98
# The cloudiness in yaan is 70
# The windspeed in yaan is 1.85
# The coordinates for yaan is 7.38
# The coordinates for yaan is 8.57
# 122
# aklavik
# The temperature in aklavik is 14.149999999999977
# The humidity in aklavik is 67
# The cloudiness in aklavik is 75
# The windspeed in aklavik is 3.1
# The coordinates for aklavik is 68.22
# The coordinates for aklavik is -135.01
# 123
# bathsheba
# The temperature in bathsheba is 28.149999999999977
# The humidity in bathsheba is 78
# The cloudiness in bathsheba is 40
# The windspeed in bathsheba is 4.6
# The coordinates for bathsheba is 13.22
# The coordinates for bathsheba is -59.52
# 124
# guanica
# The temperature in guanica is 26.889999999999986
# The humidity in guanica is 88
# The cloudiness in guanica is 90
# The windspeed in guanica is 2.1
# The coordinates for guanica is 17.97
# The coordinates for guanica is -66.91
# 125
# baykit
# The temperature in baykit is 3.7060000000000173
# The humidity in baykit is 76
# The cloudiness in baykit is 52
# The windspeed in baykit is 3.02
# The coordinates for baykit is 61.68
# The coordinates for baykit is 96.39
# 126
# fortuna
# The temperature in fortuna is 18.860000000000014
# The humidity in fortuna is 72
# The cloudiness in fortuna is 75
# The windspeed in fortuna is 5.1
# The coordinates for fortuna is 40.6
# The coordinates for fortuna is -124.16
# 127
# cayhagan
# The temperature in cayhagan is 28.305999999999983
# The humidity in cayhagan is 77
# The cloudiness in cayhagan is 100
# The windspeed in cayhagan is 4.19
# The coordinates for cayhagan is 9.67
# The coordinates for cayhagan is 122.43
# 128
# alofi
# The temperature in alofi is 28.149999999999977
# The humidity in alofi is 74
# The cloudiness in alofi is 40
# The windspeed in alofi is 2.1
# The coordinates for alofi is -19.06
# The coordinates for alofi is -169.92
# 129
# oranjemund
# The temperature in oranjemund is 12.906000000000006
# The humidity in oranjemund is 92
# The cloudiness in oranjemund is 0
# The windspeed in oranjemund is 8.74
# The coordinates for oranjemund is -28.55
# The coordinates for oranjemund is 16.43
# 130
# bredasdorp
# The temperature in bredasdorp is 13.480000000000018
# The humidity in bredasdorp is 85
# The cloudiness in bredasdorp is 100
# The windspeed in bredasdorp is 1.38
# The coordinates for bredasdorp is -34.53
# The coordinates for bredasdorp is 20.04
# 131
# severo-kurilsk
# The temperature in severo-kurilsk is 10.005999999999972
# The humidity in severo-kurilsk is 89
# The cloudiness in severo-kurilsk is 40
# The windspeed in severo-kurilsk is 10.59
# The coordinates for severo-kurilsk is 50.68
# The coordinates for severo-kurilsk is 156.12
# 132
# lolua
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 133
# hihifo
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 134
# taoudenni
# The temperature in taoudenni is 35.80599999999998
# The humidity in taoudenni is 19
# The cloudiness in taoudenni is 73
# The windspeed in taoudenni is 4.7
# The coordinates for taoudenni is 22.68
# The coordinates for taoudenni is -3.98
# 135
# colac
# The temperature in colac is 15.100000000000023
# The humidity in colac is 75
# The cloudiness in colac is 0
# The windspeed in colac is 0.45
# The coordinates for colac is -38.34
# The coordinates for colac is 143.59
# 136
# leningradskiy
# The temperature in leningradskiy is 6.305999999999983
# The humidity in leningradskiy is 91
# The cloudiness in leningradskiy is 100
# The windspeed in leningradskiy is 6.74
# The coordinates for leningradskiy is 69.38
# The coordinates for leningradskiy is 178.42
# 137
# yumen
# The temperature in yumen is 22.206000000000017
# The humidity in yumen is 37
# The cloudiness in yumen is 36
# The windspeed in yumen is 5.67
# The coordinates for yumen is 40.29
# The coordinates for yumen is 97.04
# 138
# provideniya
# The temperature in provideniya is 10.149999999999977
# The humidity in provideniya is 81
# The cloudiness in provideniya is 90
# The windspeed in provideniya is 6
# The coordinates for provideniya is 64.42
# The coordinates for provideniya is -173.23
# 139
# hamilton
# The temperature in hamilton is 22.529999999999973
# The humidity in hamilton is 78
# The cloudiness in hamilton is 75
# The windspeed in hamilton is 4.6
# The coordinates for hamilton is 43.26
# The coordinates for hamilton is -79.87
# 140
# codrington
# The temperature in codrington is 19.189999999999998
# The humidity in codrington is 45
# The cloudiness in codrington is 75
# The windspeed in codrington is 6.7
# The coordinates for codrington is -28.95
# The coordinates for codrington is 153.24
# 141
# mys shmidta
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 142
# san matias
# The temperature in san matias is 28.605999999999995
# The humidity in san matias is 23
# The cloudiness in san matias is 0
# The windspeed in san matias is 1.27
# The coordinates for san matias is -16.36
# The coordinates for san matias is -58.4
# 143
# evensk
# The temperature in evensk is 10.105999999999995
# The humidity in evensk is 56
# The cloudiness in evensk is 100
# The windspeed in evensk is 9.01
# The coordinates for evensk is 61.92
# The coordinates for evensk is 159.24
# 144
# fomboni
# The temperature in fomboni is 25.005999999999972
# The humidity in fomboni is 80
# The cloudiness in fomboni is 9
# The windspeed in fomboni is 2.93
# The coordinates for fomboni is -12.28
# The coordinates for fomboni is 43.74
# 145
# cabra
# The temperature in cabra is 15.889999999999986
# The humidity in cabra is 39
# The cloudiness in cabra is 15
# The windspeed in cabra is 4.63
# The coordinates for cabra is 37.47
# The coordinates for cabra is -4.43
# 146
# luau
# The temperature in luau is 17.206000000000017
# The humidity in luau is 26
# The cloudiness in luau is 8
# The windspeed in luau is 2.05
# The coordinates for luau is -10.7
# The coordinates for luau is 22.23
# 147
# faanui
# The temperature in faanui is 25.505999999999972
# The humidity in faanui is 80
# The cloudiness in faanui is 56
# The windspeed in faanui is 5.17
# The coordinates for faanui is -16.48
# The coordinates for faanui is -151.75
# 148
# port elizabeth
# The temperature in port elizabeth is 21.819999999999993
# The humidity in port elizabeth is 83
# The cloudiness in port elizabeth is 69
# The windspeed in port elizabeth is 2.1
# The coordinates for port elizabeth is 39.31
# The coordinates for port elizabeth is -74.98
# 149
# hami
# The temperature in hami is 21.406000000000006
# The humidity in hami is 34
# The cloudiness in hami is 99
# The windspeed in hami is 3
# The coordinates for hami is 42.84
# The coordinates for hami is 93.51
# 150
# mana
# The temperature in mana is 24.505999999999972
# The humidity in mana is 80
# The cloudiness in mana is 11
# The windspeed in mana is 3.46
# The coordinates for mana is 13.03
# The coordinates for mana is 5.27
# 151
# raudeberg
# The temperature in raudeberg is 15.149999999999977
# The humidity in raudeberg is 72
# The cloudiness in raudeberg is 100
# The windspeed in raudeberg is 12.3
# The coordinates for raudeberg is 61.99
# The coordinates for raudeberg is 5.14
# 152
# caetite
# The temperature in caetite is 17.206000000000017
# The humidity in caetite is 88
# The cloudiness in caetite is 42
# The windspeed in caetite is 4.33
# The coordinates for caetite is -14.07
# The coordinates for caetite is -42.48
# 153
# te anau
# The temperature in te anau is 7.1059999999999945
# The humidity in te anau is 63
# The cloudiness in te anau is 87
# The windspeed in te anau is 4.89
# The coordinates for te anau is -45.41
# The coordinates for te anau is 167.72
# 154
# butaritari
# The temperature in butaritari is 28.305999999999983
# The humidity in butaritari is 69
# The cloudiness in butaritari is 100
# The windspeed in butaritari is 5.32
# The coordinates for butaritari is 3.07
# The coordinates for butaritari is 172.79
# 155
# bluff
# The temperature in bluff is 23.305999999999983
# The humidity in bluff is 27
# The cloudiness in bluff is 0
# The windspeed in bluff is 5.14
# The coordinates for bluff is -23.58
# The coordinates for bluff is 149.07
# 156
# wanning
# The temperature in wanning is 10.120000000000005
# The humidity in wanning is 93
# The cloudiness in wanning is 75
# The windspeed in wanning is 0.5
# The coordinates for wanning is 48.64
# The coordinates for wanning is 13.53
# 157
# san patricio
# The temperature in san patricio is 18.105999999999995
# The humidity in san patricio is 76
# The cloudiness in san patricio is 100
# The windspeed in san patricio is 2.32
# The coordinates for san patricio is -26.98
# The coordinates for san patricio is -56.83
# 158
# thompson
# The temperature in thompson is 6.149999999999977
# The humidity in thompson is 75
# The cloudiness in thompson is 40
# The windspeed in thompson is 1.5
# The coordinates for thompson is 55.74
# The coordinates for thompson is -97.86
# 159
# sehwan
# The temperature in sehwan is 29.149999999999977
# The humidity in sehwan is 79
# The cloudiness in sehwan is 20
# The windspeed in sehwan is 3.1
# The coordinates for sehwan is 26.43
# The coordinates for sehwan is 67.86
# 160
# nola
# The temperature in nola is 19.906000000000006
# The humidity in nola is 96
# The cloudiness in nola is 80
# The windspeed in nola is 0.73
# The coordinates for nola is 3.52
# The coordinates for nola is 16.05
# 161
# barsovo
# The temperature in barsovo is 5.149999999999977
# The humidity in barsovo is 100
# The cloudiness in barsovo is 40
# The windspeed in barsovo is 4
# The coordinates for barsovo is 61.17
# The coordinates for barsovo is 73.17
# 162
# skjervoy
# The temperature in skjervoy is 10.805999999999983
# The humidity in skjervoy is 86
# The cloudiness in skjervoy is 100
# The windspeed in skjervoy is 2.86
# The coordinates for skjervoy is 70.03
# The coordinates for skjervoy is 20.97
# 163
# grand gaube
# The temperature in grand gaube is 18.139999999999986
# The humidity in grand gaube is 88
# The cloudiness in grand gaube is 40
# The windspeed in grand gaube is 3.1
# The coordinates for grand gaube is -20.01
# The coordinates for grand gaube is 57.66
# 164
# volda
# The temperature in volda is 13.879999999999995
# The humidity in volda is 93
# The cloudiness in volda is 100
# The windspeed in volda is 1.5
# The coordinates for volda is 62.15
# The coordinates for volda is 6.07
# 165
# saint-philippe
# The temperature in saint-philippe is 14.889999999999986
# The humidity in saint-philippe is 100
# The cloudiness in saint-philippe is 90
# The windspeed in saint-philippe is 4.6
# The coordinates for saint-philippe is 45.36
# The coordinates for saint-philippe is -73.48
# 166
# kloulklubed
# The temperature in kloulklubed is 29.149999999999977
# The humidity in kloulklubed is 74
# The cloudiness in kloulklubed is 90
# The windspeed in kloulklubed is 11.3
# The coordinates for kloulklubed is 7.04
# The coordinates for kloulklubed is 134.26
# 167
# tiksi
# The temperature in tiksi is 3.7060000000000173
# The humidity in tiksi is 67
# The cloudiness in tiksi is 62
# The windspeed in tiksi is 3.13
# The coordinates for tiksi is 71.64
# The coordinates for tiksi is 128.87
# 168
# hofn
# The temperature in hofn is 2.906000000000006
# The humidity in hofn is 96
# The cloudiness in hofn is 100
# The windspeed in hofn is 5.52
# The coordinates for hofn is 64.25
# The coordinates for hofn is -15.21
# 169
# arman
# The temperature in arman is 12.005999999999972
# The humidity in arman is 42
# The cloudiness in arman is 0
# The windspeed in arman is 7.3
# The coordinates for arman is 59.7
# The coordinates for arman is 150.17
# 170
# saint-augustin
# The temperature in saint-augustin is 14.769999999999982
# The humidity in saint-augustin is 100
# The cloudiness in saint-augustin is 90
# The windspeed in saint-augustin is 4.6
# The coordinates for saint-augustin is 45.63
# The coordinates for saint-augustin is -73.98
# 171
# georgetown
# The temperature in georgetown is 26.149999999999977
# The humidity in georgetown is 94
# The cloudiness in georgetown is 20
# The windspeed in georgetown is 1
# The coordinates for georgetown is 6.8
# The coordinates for georgetown is -58.16
# 172
# tuljapur
# The temperature in tuljapur is 24.505999999999972
# The humidity in tuljapur is 81
# The cloudiness in tuljapur is 99
# The windspeed in tuljapur is 7.18
# The coordinates for tuljapur is 18.01
# The coordinates for tuljapur is 76.07
# 173
# fuling
# The temperature in fuling is 29.005999999999972
# The humidity in fuling is 70
# The cloudiness in fuling is 100
# The windspeed in fuling is 1.09
# The coordinates for fuling is 29.71
# The coordinates for fuling is 107.39
# 174
# gaoua
# The temperature in gaoua is 21.605999999999995
# The humidity in gaoua is 92
# The cloudiness in gaoua is 68
# The windspeed in gaoua is 1.44
# The coordinates for gaoua is 10.33
# The coordinates for gaoua is -3.18
# 175
# paamiut
# The temperature in paamiut is 4.906000000000006
# The humidity in paamiut is 86
# The cloudiness in paamiut is 94
# The windspeed in paamiut is 5.61
# The coordinates for paamiut is 61.99
# The coordinates for paamiut is -49.67
# 176
# khani
# The temperature in khani is 19.149999999999977
# The humidity in khani is 55
# The cloudiness in khani is 0
# The windspeed in khani is 9.8
# The coordinates for khani is 41.96
# The coordinates for khani is 42.96
# 177
# tasbuget
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 178
# marsh harbour
# The temperature in marsh harbour is 28.105999999999995
# The humidity in marsh harbour is 77
# The cloudiness in marsh harbour is 6
# The windspeed in marsh harbour is 9.02
# The coordinates for marsh harbour is 26.54
# The coordinates for marsh harbour is -77.06
# 179
# kaspiysk
# The temperature in kaspiysk is 20.55000000000001
# The humidity in kaspiysk is 72
# The cloudiness in kaspiysk is 97
# The windspeed in kaspiysk is 2
# The coordinates for kaspiysk is 42.88
# The coordinates for kaspiysk is 47.64
# 180
# henties bay
# The temperature in henties bay is 12.930000000000007
# The humidity in henties bay is 90
# The cloudiness in henties bay is 0
# The windspeed in henties bay is 1.34
# The coordinates for henties bay is -22.12
# The coordinates for henties bay is 14.28
# 181
# kizilskoye
# The temperature in kizilskoye is 8.706000000000017
# The humidity in kizilskoye is 86
# The cloudiness in kizilskoye is 0
# The windspeed in kizilskoye is 1.19
# The coordinates for kizilskoye is 52.73
# The coordinates for kizilskoye is 58.89
# 182
# wasilla
# The temperature in wasilla is 13.089999999999975
# The humidity in wasilla is 87
# The cloudiness in wasilla is 90
# The windspeed in wasilla is 1.5
# The coordinates for wasilla is 61.58
# The coordinates for wasilla is -149.44
# 183
# neiafu
# The temperature in neiafu is 28.149999999999977
# The humidity in neiafu is 78
# The cloudiness in neiafu is 40
# The windspeed in neiafu is 2.6
# The coordinates for neiafu is -18.65
# The coordinates for neiafu is -173.98
# 184
# laguna
# The temperature in laguna is 27.149999999999977
# The humidity in laguna is 88
# The cloudiness in laguna is 40
# The windspeed in laguna is 1.48
# The coordinates for laguna is 16.17
# The coordinates for laguna is -88.94
# 185
# xichang
# The temperature in xichang is 19.805999999999983
# The humidity in xichang is 83
# The cloudiness in xichang is 99
# The windspeed in xichang is 1.21
# The coordinates for xichang is 27.88
# The coordinates for xichang is 102.25
# 186
# marathon
# The temperature in marathon is 7.906000000000006
# The humidity in marathon is 97
# The cloudiness in marathon is 100
# The windspeed in marathon is 4.42
# The coordinates for marathon is 48.72
# The coordinates for marathon is -86.38
# 187
# barentsburg
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 188
# noyon
# The temperature in noyon is 10.100000000000023
# The humidity in noyon is 87
# The cloudiness in noyon is 0
# The windspeed in noyon is 2.1
# The coordinates for noyon is 49.58
# The coordinates for noyon is 3
# 189
# fort-shevchenko
# The temperature in fort-shevchenko is 21.105999999999995
# The humidity in fort-shevchenko is 49
# The cloudiness in fort-shevchenko is 0
# The windspeed in fort-shevchenko is 6.3
# The coordinates for fort-shevchenko is 44.51
# The coordinates for fort-shevchenko is 50.26
# 190
# werota
# The temperature in werota is 19.605999999999995
# The humidity in werota is 77
# The cloudiness in werota is 100
# The windspeed in werota is 4.87
# The coordinates for werota is 11.92
# The coordinates for werota is 37.7
# 191
# nikolskoye
# The temperature in nikolskoye is 15.920000000000016
# The humidity in nikolskoye is 87
# The cloudiness in nikolskoye is 0
# The windspeed in nikolskoye is 3
# The coordinates for nikolskoye is 59.7
# The coordinates for nikolskoye is 30.79
# 192
# tsihombe
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 193
# teya
# The temperature in teya is 27.019999999999982
# The humidity in teya is 74
# The cloudiness in teya is 90
# The windspeed in teya is 2.6
# The coordinates for teya is 21.05
# The coordinates for teya is -89.07
# 194
# nizhneyansk
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 195
# ho
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 196
# barrow
# The temperature in barrow is 4.805999999999983
# The humidity in barrow is 95
# The cloudiness in barrow is 70
# The windspeed in barrow is 2.05
# The coordinates for barrow is -38.31
# The coordinates for barrow is -60.23
# 197
# slevik
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 198
# manta
# The temperature in manta is 13.906000000000006
# The humidity in manta is 67
# The cloudiness in manta is 0
# The windspeed in manta is 1.49
# The coordinates for manta is 45.1
# The coordinates for manta is 24.1
# 199
# yarmouth
# The temperature in yarmouth is 12.329999999999984
# The humidity in yarmouth is 93
# The cloudiness in yarmouth is 90
# The windspeed in yarmouth is 2.1
# The coordinates for yarmouth is 43.84
# The coordinates for yarmouth is -66.12
# 200
# broken hill
# The temperature in broken hill is 18.149999999999977
# The humidity in broken hill is 25
# The cloudiness in broken hill is 0
# The windspeed in broken hill is 2.6
# The coordinates for broken hill is -31.97
# The coordinates for broken hill is 141.45
# 201
# lavrentiya
# The temperature in lavrentiya is 7.805999999999983
# The humidity in lavrentiya is 97
# The cloudiness in lavrentiya is 100
# The windspeed in lavrentiya is 1.83
# The coordinates for lavrentiya is 65.58
# The coordinates for lavrentiya is -170.99
# 202
# koster
# The temperature in koster is 9.605999999999995
# The humidity in koster is 36
# The cloudiness in koster is 0
# The windspeed in koster is 1.72
# The coordinates for koster is -25.86
# The coordinates for koster is 26.9
# 203
# bestobe
# The temperature in bestobe is 11.805999999999983
# The humidity in bestobe is 68
# The cloudiness in bestobe is 85
# The windspeed in bestobe is 6.88
# The coordinates for bestobe is 52.5
# The coordinates for bestobe is 73.1
# 204
# luderitz
# The temperature in luderitz is 14.149999999999977
# The humidity in luderitz is 87
# The cloudiness in luderitz is 73
# The windspeed in luderitz is 3.6
# The coordinates for luderitz is -26.65
# The coordinates for luderitz is 15.16
# 205
# dambulla
# The temperature in dambulla is 28.706000000000017
# The humidity in dambulla is 67
# The cloudiness in dambulla is 99
# The windspeed in dambulla is 6.52
# The coordinates for dambulla is 7.87
# The coordinates for dambulla is 80.65
# 206
# vaitape
# The temperature in vaitape is 25.505999999999972
# The humidity in vaitape is 80
# The cloudiness in vaitape is 56
# The windspeed in vaitape is 5.17
# The coordinates for vaitape is -16.52
# The coordinates for vaitape is -151.75
# 207
# tessalit
# The temperature in tessalit is 35.105999999999995
# The humidity in tessalit is 19
# The cloudiness in tessalit is 57
# The windspeed in tessalit is 3.73
# The coordinates for tessalit is 20.2
# The coordinates for tessalit is 1.01
# 208
# pisco
# The temperature in pisco is 16.19999999999999
# The humidity in pisco is 82
# The cloudiness in pisco is 75
# The windspeed in pisco is 7.7
# The coordinates for pisco is -13.71
# The coordinates for pisco is -76.2
# 209
# santa cruz de tenerife
# The temperature in santa cruz de tenerife is 20.20999999999998
# The humidity in santa cruz de tenerife is 88
# The cloudiness in santa cruz de tenerife is 75
# The windspeed in santa cruz de tenerife is 5.1
# The coordinates for santa cruz de tenerife is 28.47
# The coordinates for santa cruz de tenerife is -16.25
# 210
# nara
# The temperature in nara is 32.24000000000001
# ...
#  long is not available
# 565
# kharp
# The temperature in kharp is 1.0059999999999718
# The humidity in kharp is 85
# The cloudiness in kharp is 100
# The windspeed in kharp is 3.47
# The coordinates for kharp is 66.82
# The coordinates for kharp is 65.8
# 566
# kirkenaer
# The temperature in kirkenaer is 13.70999999999998
# The humidity in kirkenaer is 100
# The cloudiness in kirkenaer is 75
# The windspeed in kirkenaer is 1
# The coordinates for kirkenaer is 60.46
# The coordinates for kirkenaer is 12.06
# 567
# opuwo
# The temperature in opuwo is 9.105999999999995
# The humidity in opuwo is 76
# The cloudiness in opuwo is 0
# The windspeed in opuwo is 0.3
# The coordinates for opuwo is -18.06
# The coordinates for opuwo is 13.84
# 568
# maceio
# The temperature in maceio is 21.149999999999977
# The humidity in maceio is 94
# The cloudiness in maceio is 0
# The windspeed in maceio is 1.09
# The coordinates for maceio is -9.67
# The coordinates for maceio is -35.74
# 569
# nicoya
# The temperature in nicoya is 25.279999999999973
# The humidity in nicoya is 69
# The cloudiness in nicoya is 0
# The windspeed in nicoya is 3.1
# The coordinates for nicoya is 10.15
# The coordinates for nicoya is -85.45
# 570
# ndele
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 571
# nanga eboko
# The temperature in nanga eboko is 19.505999999999972
# The humidity in nanga eboko is 99
# The cloudiness in nanga eboko is 87
# The windspeed in nanga eboko is 1.47
# The coordinates for nanga eboko is 4.68
# The coordinates for nanga eboko is 12.37
# 572
# guatire
# The temperature in guatire is 24.279999999999973
# The humidity in guatire is 78
# The cloudiness in guatire is 75
# The windspeed in guatire is 3.1
# The coordinates for guatire is 10.47
# The coordinates for guatire is -66.54
# 573
# luanda
# The temperature in luanda is 23.149999999999977
# The humidity in luanda is 94
# The cloudiness in luanda is 75
# The windspeed in luanda is 3.6
# The coordinates for luanda is -8.83
# The coordinates for luanda is 13.24
# 574
# aanekoski
# The temperature in aanekoski is 9.660000000000025
# The humidity in aanekoski is 100
# The cloudiness in aanekoski is 90
# The windspeed in aanekoski is 0.5
# The coordinates for aanekoski is 62.6
# The coordinates for aanekoski is 25.73
# 575
# kostomuksha
# The temperature in kostomuksha is 10.805999999999983
# The humidity in kostomuksha is 96
# The cloudiness in kostomuksha is 13
# The windspeed in kostomuksha is 1.78
# The coordinates for kostomuksha is 64.59
# The coordinates for kostomuksha is 30.6
# 576
# high rock
# The temperature in high rock is 28.105999999999995
# The humidity in high rock is 77
# The cloudiness in high rock is 2
# The windspeed in high rock is 8.22
# The coordinates for high rock is 26.63
# The coordinates for high rock is -78.28
# 577
# mount isa
# The temperature in mount isa is 24.149999999999977
# The humidity in mount isa is 11
# The cloudiness in mount isa is 0
# The windspeed in mount isa is 6.7
# The coordinates for mount isa is -20.73
# The coordinates for mount isa is 139.49
# 578
# fevralsk
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 579
# kincardine
# The temperature in kincardine is 21.089999999999975
# The humidity in kincardine is 93
# The cloudiness in kincardine is 99
# The windspeed in kincardine is 5.89
# The coordinates for kincardine is 44.18
# The coordinates for kincardine is -81.63
# 580
# ankazoabo
# The temperature in ankazoabo is 16.406000000000006
# The humidity in ankazoabo is 93
# The cloudiness in ankazoabo is 5
# The windspeed in ankazoabo is 0.66
# The coordinates for ankazoabo is -22.29
# The coordinates for ankazoabo is 44.51
# 581
# nenjiang
# The temperature in nenjiang is 16.505999999999972
# The humidity in nenjiang is 57
# The cloudiness in nenjiang is 0
# The windspeed in nenjiang is 2.63
# The coordinates for nenjiang is 49.17
# The coordinates for nenjiang is 125.23
# 582
# uniontown
# The temperature in uniontown is 21.54000000000002
# The humidity in uniontown is 77
# The cloudiness in uniontown is 1
# The windspeed in uniontown is 3.6
# The coordinates for uniontown is 39.9
# The coordinates for uniontown is -79.72
# 583
# mogadishu
# The temperature in mogadishu is 25.149999999999977
# The humidity in mogadishu is 73
# The cloudiness in mogadishu is 40
# The windspeed in mogadishu is 6.2
# The coordinates for mogadishu is 2.04
# The coordinates for mogadishu is 45.34
# 584
# jahrom
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 585
# quatre cocos
# The temperature in quatre cocos is 18.139999999999986
# The humidity in quatre cocos is 93
# The cloudiness in quatre cocos is 40
# The windspeed in quatre cocos is 2.6
# The coordinates for quatre cocos is -20.21
# The coordinates for quatre cocos is 57.76
# 586
# yakeshi
# The temperature in yakeshi is 17.005999999999972
# The humidity in yakeshi is 47
# The cloudiness in yakeshi is 0
# The windspeed in yakeshi is 4.19
# The coordinates for yakeshi is 49.28
# The coordinates for yakeshi is 120.73
# 587
# odda
# The temperature in odda is 12.930000000000007
# The humidity in odda is 77
# The cloudiness in odda is 100
# The windspeed in odda is 4.92
# The coordinates for odda is 60.07
# The coordinates for odda is 6.55
# 588
# ngukurr
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 589
# mao
# The temperature in mao is 23.480000000000018
# The humidity in mao is 100
# The cloudiness in mao is 75
# The windspeed in mao is 1.31
# The coordinates for mao is 19.55
# The coordinates for mao is -71.08
# 590
# smithers
# The temperature in smithers is 16.149999999999977
# The humidity in smithers is 59
# The cloudiness in smithers is 75
# The windspeed in smithers is 3.1
# The coordinates for smithers is 54.78
# The coordinates for smithers is -127.17
# 591
# tocopilla
# The temperature in tocopilla is 15.305999999999983
# The humidity in tocopilla is 79
# The cloudiness in tocopilla is 43
# The windspeed in tocopilla is 5.37
# The coordinates for tocopilla is -22.09
# The coordinates for tocopilla is -70.2
# 592
# galiwinku
#  temp is not available
#  humidity is not available
#  cloudiness is not available
#  wind_speed is not available
#  lat is not available
#  long is not available
# 593
# goderich
# The temperature in goderich is 22.24000000000001
# The humidity in goderich is 85
# The cloudiness in goderich is 100
# The windspeed in goderich is 7.69
# The coordinates for goderich is 43.74
# The coordinates for goderich is -81.71
# 594
# leshukonskoye
# The temperature in leshukonskoye is 12.305999999999983
# The humidity in leshukonskoye is 96
# The cloudiness in leshukonskoye is 99
# The windspeed in leshukonskoye is 3.06
# The coordinates for leshukonskoye is 64.9
# The coordinates for leshukonskoye is 45.76
# 595
# lins
# The temperature in lins is 26.105999999999995
# The humidity in lins is 45
# The cloudiness in lins is 79
# The windspeed in lins is 3.83
# The coordinates for lins is -21.67
# The coordinates for lins is -49.75
# 596
# santa fe
# The temperature in santa fe is 14.860000000000014
# The humidity in santa fe is 83
# The cloudiness in santa fe is 91
# The windspeed in santa fe is 1.34
# The coordinates for santa fe is -31.62
# The coordinates for santa fe is -60.7
# 597
# bela palanka
# The temperature in bela palanka is 17.149999999999977
# The humidity in bela palanka is 72
# The cloudiness in bela palanka is 0
# The windspeed in bela palanka is 2.1
# The coordinates for bela palanka is 43.22
# The coordinates for bela palanka is 22.31
# 598
# yurimaguas
# The temperature in yurimaguas is 22.305999999999983
# The humidity in yurimaguas is 79
# The cloudiness in yurimaguas is 12
# The windspeed in yurimaguas is 1.91
# The coordinates for yurimaguas is -5.9
# The coordinates for yurimaguas is -76.1
# 599
# hervey bay
# The temperature in hervey bay is 24
# The humidity in hervey bay is 38
# The cloudiness in hervey bay is 40
# The windspeed in hervey bay is 6.7
# The coordinates for hervey bay is -25.3
# The coordinates for hervey bay is 152.85
# 600
# conakry
# The temperature in conakry is 25.805999999999983
# The humidity in conakry is 85
# The cloudiness in conakry is 100
# The windspeed in conakry is 2.35
# The coordinates for conakry is 9.52
# The coordinates for conakry is -13.7
# 601
# mandalgovi
# The temperature in mandalgovi is 19.605999999999995
# The humidity in mandalgovi is 46
# The cloudiness in mandalgovi is 78
# The windspeed in mandalgovi is 7.07
# The coordinates for mandalgovi is 45.76
# The coordinates for mandalgovi is 106.27
# 602
# sume
# The temperature in sume is 11.579999999999984
# The humidity in sume is 100
# The cloudiness in sume is 0
# The windspeed in sume is 0.42
# The coordinates for sume is 43.62
# The coordinates for sume is 20.22
# 603
# mastic beach
# The temperature in mastic beach is 20.69999999999999
# The humidity in mastic beach is 88
# The cloudiness in mastic beach is 1
# The windspeed in mastic beach is 2.1
# The coordinates for mastic beach is 40.77
# The coordinates for mastic beach is -72.85
# 604
# ust-tsilma
# The temperature in ust-tsilma is 8.906000000000006
# The humidity in ust-tsilma is 93
# The cloudiness in ust-tsilma is 42
# The windspeed in ust-tsilma is 1.7
# The coordinates for ust-tsilma is 65.44
# The coordinates for ust-tsilma is 52.15
# 605
# gwanda
# The temperature in gwanda is 13.805999999999983
# The humidity in gwanda is 26
# The cloudiness in gwanda is 0
# The windspeed in gwanda is 1.96
# The coordinates for gwanda is -20.94
# The coordinates for gwanda is 29
#          City Name Temperature  Humidity  Cloudiness Wind Speed Latitude  \
# 0             tura       7.406      59.0        74.0       4.55    64.27
# 1          mataura       10.15      71.0        98.0       5.36   -46.19
# 2       nelson bay       17.75      59.0        75.0        6.2   -32.72
# 3            airai      28.806      37.0        61.0       0.99    -8.93
# 4           xiamen       31.15      62.0        40.0          1    24.46
# 5         tasiilaq        4.15      80.0         0.0        2.6    65.61
# 6        taolanaro        4.15      80.0         0.0        2.6    65.61
# 7          ushuaia        6.15      70.0        75.0        1.5   -54.81
# 8            rocha       9.606      91.0       100.0       1.75   -34.48
# 9          syamzha      12.206      97.0         2.0        2.1    60.02
# 10        kirakira      26.406      88.0       100.0       8.56   -10.46
# 11       hithadhoo      29.006      68.0        37.0       2.93     -0.6
# 12          albany       20.33      69.0        75.0        5.1    42.65
# 13    punta arenas        6.46      75.0        40.0        8.2   -53.16
# 14      prior lake       18.94      88.0         1.0       2.54    44.71
# 15        dong hoi      30.706      61.0        88.0       1.62    17.48
# 16      nanortalik       4.106      88.0       100.0        2.1    60.14
# 17          urumqi       4.106      88.0       100.0        2.1    60.14
# 18    ponta do sol      22.106      40.0        78.0       1.59   -20.63
# 19         rikitea      22.506      81.0        49.0       7.75   -23.12
# 20       saskylakh       4.006      88.0       100.0       5.93    71.97
# 21         meyungs       4.006      88.0       100.0       5.93    71.97
# 22      kaitangata       8.806      60.0        91.0       5.07   -46.28
# 23        hermanus       14.04      84.0        34.0       0.45   -34.42
# 24        progreso        9.46      87.0        20.0        2.1   -34.68
# 25         marcona        9.46      87.0        20.0        2.1   -34.68
# 26         estelle       18.15      63.0         0.0        4.1    43.97
# 27          bonthe      23.906      94.0       100.0       3.09     7.53
# 28          atuona      26.706      73.0        76.0       7.34     -9.8
# 29          wajima       28.15      78.0        75.0        4.6     37.4
# ..             ...         ...       ...         ...        ...      ...
# 576      high rock      28.106      77.0         2.0       8.22    26.63
# 577      mount isa       24.15      11.0         0.0        6.7   -20.73
# 578       fevralsk       24.15      11.0         0.0        6.7   -20.73
# 579     kincardine       21.09      93.0        99.0       5.89    44.18
# 580      ankazoabo      16.406      93.0         5.0       0.66   -22.29
# 581       nenjiang      16.506      57.0         0.0       2.63    49.17
# 582      uniontown       21.54      77.0         1.0        3.6     39.9
# 583      mogadishu       25.15      73.0        40.0        6.2     2.04
# 584         jahrom       25.15      73.0        40.0        6.2     2.04
# 585   quatre cocos       18.14      93.0        40.0        2.6   -20.21
# 586        yakeshi      17.006      47.0         0.0       4.19    49.28
# 587           odda       12.93      77.0       100.0       4.92    60.07
# 588        ngukurr       12.93      77.0       100.0       4.92    60.07
# 589            mao       23.48     100.0        75.0       1.31    19.55
# 590       smithers       16.15      59.0        75.0        3.1    54.78
# 591      tocopilla      15.306      79.0        43.0       5.37   -22.09
# 592      galiwinku      15.306      79.0        43.0       5.37   -22.09
# 593       goderich       22.24      85.0       100.0       7.69    43.74
# 594  leshukonskoye      12.306      96.0        99.0       3.06     64.9
# 595           lins      26.106      45.0        79.0       3.83   -21.67
# 596       santa fe       14.86      83.0        91.0       1.34   -31.62
# 597   bela palanka       17.15      72.0         0.0        2.1    43.22
# 598     yurimaguas      22.306      79.0        12.0       1.91     -5.9
# 599     hervey bay          24      38.0        40.0        6.7    -25.3
# 600        conakry      25.806      85.0       100.0       2.35     9.52
# 601     mandalgovi      19.606      46.0        78.0       7.07    45.76
# 602           sume       11.58     100.0         0.0       0.42    43.62
# 603   mastic beach        20.7      88.0         1.0        2.1    40.77
# 604     ust-tsilma       8.906      93.0        42.0        1.7    65.44
# 605         gwanda      13.806      26.0         0.0       1.96   -20.94
#
#     Longitiude  Longititude
# 0          NaN       100.22
# 1          NaN       168.86
# 2          NaN       152.14
# 3          NaN       125.41
# 4          NaN       118.07
# 5          NaN       -37.64
# 6          NaN       -37.64
# 7          NaN       -68.31
# 8          NaN       -54.34
# 9          NaN        41.06
# 10         NaN       161.92
# 11         NaN        73.08
# 12         NaN       -73.75
# 13         NaN       -70.91
# 14         NaN       -93.42
# 15         NaN       106.60
# 16         NaN       -45.24
# 17         NaN       -45.24
# 18         NaN       -46.00
# 19         NaN      -134.97
# 20         NaN       114.09
# 21         NaN       114.09
# 22         NaN       169.85
# 23         NaN        19.24
# 24         NaN       -56.22
# 25         NaN       -56.22
# 26         NaN         3.47
# 27         NaN       -12.50
# 28         NaN      -139.03
# 29         NaN       136.90
# ..         ...          ...
# 576        NaN       -78.28
# 577        NaN       139.49
# 578        NaN       139.49
# 579        NaN       -81.63
# 580        NaN        44.51
# 581        NaN       125.23
# 582        NaN       -79.72
# 583        NaN        45.34
# 584        NaN        45.34
# 585        NaN        57.76
# 586        NaN       120.73
# 587        NaN         6.55
# 588        NaN         6.55
# 589        NaN       -71.08
# 590        NaN      -127.17
# 591        NaN       -70.20
# 592        NaN       -70.20
# 593        NaN       -81.71
# 594        NaN        45.76
# 595        NaN       -49.75
# 596        NaN       -60.70
# 597        NaN        22.31
# 598        NaN       -76.10
# 599        NaN       152.85
# 600        NaN       -13.70
# 601        NaN       106.27
# 602        NaN        20.22
# 603        NaN       -72.85
# 604        NaN        52.15
# 605        NaN        29.00
#
# [606 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather.to_csv("homework.csv")

# %%
weather_data = pd.read_csv("homework.csv")
weather_data.head()
# Out:
#    Unnamed: 0   City Name  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0           0        tura        7.406      59.0        74.0        4.55
# 1           1     mataura       10.150      71.0        98.0        5.36
# 2           2  nelson bay       17.750      59.0        75.0        6.20
# 3           3       airai       28.806      37.0        61.0        0.99
# 4           4      xiamen       31.150      62.0        40.0        1.00
#
#    Latitude  Longitiude  Longititude
# 0     64.27         NaN       100.22
# 1    -46.19         NaN       168.86
# 2    -32.72         NaN       152.14
# 3     -8.93         NaN       125.41
# 4     24.46         NaN       118.07

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], marker="o", s=10)

plt.title("Latitude vs.Temperature")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o", s=10)

plt.title("Latitude vs.Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o", s=10)

plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o", s=10)

plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
